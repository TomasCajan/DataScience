# %% [markdown]
# <a href="https://colab.research.google.com/github/TomasCajan/DataScience/blob/main/P4_Machine_Alignment_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Welcome to my project Machine Alignment Prediction v2**
#
# In this particular one, the goal is to re-make the previously completed case study and push it to the limits.
# Main milestones are following :
#
# 1.   Introduce a more meaningfull and reproductible Feature Selection process
# 2.   Automate the Data Mining process as much as possible
# 3.   Improve model interpretability of selected models and EDA of feature relations.
# 4.   Beat the scores of previously made predictions

# %%
# !wget https://raw.githubusercontent.com/TomasCajan/DataScience/main/Data/train_target.csv
# !wget https://raw.githubusercontent.com/TomasCajan/DataScience/main/Data/train_query.csv
# !wget https://raw.githubusercontent.com/TomasCajan/DataScience/main/Data/test_target.csv
# !wget https://raw.githubusercontent.com/TomasCajan/DataScience/main/Data/test_query.csv
# Out:
# --2023-06-07 06:08:48--  https://raw.githubusercontent.com/TomasCajan/DataScience/main/Data/train_target.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27107 (26K) [text/plain]
# Saving to: ‘train_target.csv’
#
# train_target.csv    100%[===================>]  26.47K  --.-KB/s    in 0.002s
#
# 2023-06-07 06:08:49 (12.9 MB/s) - ‘train_target.csv’ saved [27107/27107]
#
# --2023-06-07 06:08:49--  https://raw.githubusercontent.com/TomasCajan/DataScience/main/Data/train_query.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27098 (26K) [text/plain]
# Saving to: ‘train_query.csv’
#
# train_query.csv     100%[===================>]  26.46K  --.-KB/s    in 0.001s
#
# 2023-06-07 06:08:49 (28.6 MB/s) - ‘train_query.csv’ saved [27098/27098]
#
# --2023-06-07 06:08:49--  https://raw.githubusercontent.com/TomasCajan/DataScience/main/Data/test_target.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13561 (13K) [text/plain]
# Saving to: ‘test_target.csv’
#
# test_target.csv     100%[===================>]  13.24K  --.-KB/s    in 0s
#
# 2023-06-07 06:08:49 (67.6 MB/s) - ‘test_target.csv’ saved [13561/13561]
#
# --2023-06-07 06:08:49--  https://raw.githubusercontent.com/TomasCajan/DataScience/main/Data/test_query.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13567 (13K) [text/plain]
# Saving to: ‘test_query.csv’
#
# test_query.csv      100%[===================>]  13.25K  --.-KB/s    in 0s
#
# 2023-06-07 06:08:50 (86.2 MB/s) - ‘test_query.csv’ saved [13567/13567]

# %%
# !pip install --quiet shap
# !pip install --quiet feature_engine
# !pip install --quiet plotly --upgrade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.4/319.4 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 47.1 MB/s eta 0:00:00

# %%
# Load data

import pandas as pd
train_target = pd.read_csv('train_target.csv')
train_query = pd.read_csv('train_query.csv')
test_target = pd.read_csv('test_target.csv')
test_query = pd.read_csv('test_query.csv')

# %%
train_target.iloc[:17,:]
# Out:
#     ID                                       Alignment       Parameter  \
# 0    2         Instrument.Alignments.Optics.MdTLDAlign               X
# 1    2  Instrument.Alignments.Optics.AlignCorrAngleUHR  [0.004;2000].Y
# 2    2    Instrument.Alignments.Optics.CorrStigUppYUHR  [0.002;1000].X
# 3    2      Instrument.Alignments.Optics.MdSShiftTube3               Y
# 4    2  Instrument.Alignments.Optics.ShiftCorrAngleUHR        [1000].X
# 5    2      Instrument.Alignments.Optics.MdSImRotCheb1             NaN
# 6    2         Instrument.Alignments.Optics.MdSDeflACF       [0.001].X
# 7    2          Instrument.Alignments.Optics.MdDeflACF               Y
# 8    2         Instrument.Alignments.Optics.MdACRotUpp               Y
# 9    2       Instrument.Alignments.Optics.MdCompUHRRem             NaN
# 10   2         Instrument.Alignments.Optics.MdACRotLow               Y
# 11   2        Instrument.Alignments.Detectors.TLD.Push             NaN
# 12   2          Instrument.Alignments.Optics.MdDeflDC1               X
# 13   2           Instrument.Alignments.Optics.MdHRpar4             NaN
# 14   2      Instrument.Alignments.Optics.MdSImRotCheb0             NaN
# 15   2        Instrument.Alignments.Optics.MdHRSatPar1             NaN
# 16  18         Instrument.Alignments.Optics.MdTLDAlign               X
#
#          Value
# 0    -0.081250
# 1     0.000049
# 2    -0.006568
# 3   -47.505291
# 4    -0.000688
# 5     0.358900
# 6     0.127467
# 7     0.134068
# 8    -0.000980
# 9    -5.000000
# 10   -0.003041
# 11 -145.094374
# 12    0.145636
# 13    0.000009
# 14   -1.608992
# 15  -21.348815
# 16   -0.055208

# %%
# Parse data into more efficient shape for Pandas

train_target = train_target.pivot(index='ID', columns='Alignment', values='Value')
train_query = train_query.pivot(index='ID', columns='Alignment', values='Value')
test_target = test_target.pivot(index='ID', columns='Alignment', values='Value')
test_query = test_query.pivot(index='ID', columns='Alignment', values='Value')

# %%
# Clean up shared column names for better visual appeal

common_col_names = ['Instrument.Alignments.Optics.', 'Instrument.Alignments.Detectors.']
new_columns = train_target.columns.copy()
for common_col_name in common_col_names:
  new_columns = [col.replace(common_col_name, '') for col in new_columns]

train_target.columns = new_columns
train_query.columns = new_columns
test_target.columns = new_columns
test_query.columns = new_columns

train_target.columns
# Out:
# Index(['TLD.Push', 'AlignCorrAngleUHR', 'CorrStigUppYUHR', 'MdACRotLow',
#        'MdACRotUpp', 'MdCompUHRRem', 'MdDeflACF', 'MdDeflDC1', 'MdHRSatPar1',
#        'MdHRpar4', 'MdSDeflACF', 'MdSImRotCheb0', 'MdSImRotCheb1',
#        'MdSShiftTube3', 'MdTLDAlign', 'ShiftCorrAngleUHR'],
#       dtype='object')

# %%
test_target.shape
# Out:
# (12, 16)

# %%
# imports
import numpy as np
import copy

# Pre Processing
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler, MaxAbsScaler
from scipy.stats import skew 

# Evaluation
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV, train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, mean_gamma_deviance
from scipy import stats

from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# Visualization
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import seaborn as sns
import plotly.graph_objs as go
import plotly.express as px 
import plotly.figure_factory as ff
import plotly.subplots as sp
from plotly.subplots import make_subplots
from sklearn.inspection import permutation_importance
import shap
import networkx as nx
from IPython.display import display
import ipywidgets as widgets
from ipywidgets import GridspecLayout

# Feature selection
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import f_regression
from sklearn.manifold import TSNE
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import SelectKBest, SelectPercentile
from feature_engine.selection import DropCorrelatedFeatures, SmartCorrelatedSelection
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SequentialFeatureSelector as SFS
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from feature_engine.selection import SelectByShuffling
from sklearn.decomposition import PCA
from sklearn.neighbors import kneighbors_graph

from feature_engine.selection import (
    RecursiveFeatureElimination,
    DropConstantFeatures,
    DropDuplicateFeatures,
)

import warnings
warnings.filterwarnings('ignore')

# %%
# Prepare main dataframe for work
def feature_prep(before: pd.DataFrame, after: pd.DataFrame, target_feature: str) -> pd.DataFrame:

    target = after[[target_feature]].rename(columns={target_feature: f'{target_feature}_target'})
    merged = pd.concat([before, target], axis=1)
    merged = merged.reset_index()
    merged = merged.drop('ID', axis=1)

    return merged

# Feature selection - Correlation based methods
def featEngineCorr(method, threshold, model, scoring, X, y, Xtest):

  sel = SmartCorrelatedSelection(
      variables=None,
      method=method,
      threshold=threshold,
      missing_values="raise",
      selection_method="model_performance",
      estimator=model,
      scoring=scoring,
      cv=3,
  )

  sel.fit(X, y)
  feature_grp = sel.correlated_feature_sets_
  feature_transformed = sel.transform(X)
  feature_kept = feature_transformed.columns
  feature_transformed_test = Xtest.loc[:,feature_kept]

  return feature_transformed, feature_kept, feature_transformed_test

def corData(dataframe, target_feature, mth):

    corr_d = dataframe.corr(method = mth)[[target_feature]]
    return corr_d

# Feature selection - PCA
def fsPCA(X, Xtest, strategy):

  numerical_columns = X.select_dtypes(include=['float64', 'int64']).columns

  if strategy == "MinMax":
    scaler = MinMaxScaler()
    df_scaled = scaler.fit_transform(X)
    df_scaled_test = scaler.fit_transform(Xtest)
    X_scaled_df = pd.DataFrame(df_scaled, columns=numerical_columns)
    X_scaled_df_test = pd.DataFrame(df_scaled_test, columns=numerical_columns)

  if strategy == "Mean_norm":
    scaler_mean_train = StandardScaler(with_mean = True, with_std = False)
    scaler_mean_test = StandardScaler(with_mean = True, with_std = False)
    scaler_minmax_train = RobustScaler(with_centering = False, with_scaling = True, quantile_range = (0,100))
    scaler_minmax_test = RobustScaler(with_centering = False, with_scaling = True, quantile_range = (0,100))
    scaler_mean_train.fit(X)
    scaler_minmax_train.fit(X)
    scaler_mean_test.fit(Xtest)
    scaler_minmax_test.fit(Xtest)
    df_scaled = scaler_minmax_train.transform(scaler_mean_train.transform(X))
    df_scaled_test = scaler_minmax_test.transform(scaler_mean_test.transform(Xtest))
    X_scaled_df = pd.DataFrame(df_scaled, columns=numerical_columns)
    X_scaled_df_test = pd.DataFrame(df_scaled_test, columns=numerical_columns)

  if strategy == "MMS":
    scaler_mean_train = StandardScaler(with_mean = True, with_std = False)
    scaler_mean_test = StandardScaler(with_mean = True, with_std = False)
    scaler_minmax_train = MinMaxScaler()
    scaler_minmax_test = MinMaxScaler()
    scaler_mean_train.fit(X)
    scaler_minmax_train.fit(X)
    scaler_mean_test.fit(Xtest)
    scaler_minmax_test.fit(Xtest)
    df_scaled  = scaler_mean_train.transform(scaler_minmax_train.transform(X))
    df_scaled_test = scaler_mean_test.transform(scaler_minmax_test.transform(Xtest))
    X_scaled_df = pd.DataFrame(df_scaled, columns=numerical_columns)
    X_scaled_df_test = pd.DataFrame(df_scaled_test, columns=numerical_columns)

  pca = PCA()
  X_pca = pca.fit_transform(X_scaled_df)

  explained_variance_ratio = pca.explained_variance_ratio_
  cumulative_variance_ratio = np.cumsum(explained_variance_ratio)

  threshold_variance = 0.95 
  num_components = np.argmax(cumulative_variance_ratio >= threshold_variance) + 1

  selected_components = X_pca[:, :num_components]
  selected_components_df = pd.DataFrame(selected_components, columns=X.columns[:num_components])
  feature_kept = selected_components_df.columns
  feature_transformed_test = X_scaled_df_test.loc[:,feature_kept]

  return selected_components_df , feature_kept, feature_transformed_test

# Feature selection - Laplacian method
def fsLaplacian(X, y, Xtest):

  X_array = X.values
  y_array = y.values
  k = 6

  graph = kneighbors_graph(X_array, n_neighbors=k)
  laplacian_selector = SelectKBest(score_func=f_regression, k=k)
  laplacian_selector.fit(X_array, y_array)

  selected_features = laplacian_selector.get_support()
  selected_feature_names = X.columns[selected_features]

  df_laplacian = X.loc[:,selected_feature_names]
  df_laplacian_test = Xtest.loc[:,selected_feature_names]

  return df_laplacian, selected_feature_names, df_laplacian_test

# Feature selection - Statistical methods
def statsFs(methd, X, y, Xtest):

  if methd == "mi":
    selector = mutual_info_regression(X, y, random_state= 101)
    selector = pd.Series(selector)
    sel_ = SelectPercentile(mutual_info_regression, percentile=20).fit(X, y)
    feature_kept = X.columns[sel_.get_support()]
    feature_transformed = sel_.transform(X)
    feature_transformed_df = pd.DataFrame(feature_transformed)
    feature_transformed_test = Xtest.loc[:,feature_kept]

  elif methd == "anova":
    selector = f_regression(X, y)
    selector = pd.Series(selector[1])
    sel_ = SelectPercentile(f_regression, percentile=25).fit(X, y)
    feature_kept = X.columns[sel_.get_support()]
    feature_transformed = sel_.transform(X)
    feature_transformed_df = pd.DataFrame(feature_transformed)
    feature_transformed_test = Xtest.loc[:,feature_kept]

  return feature_transformed_df, feature_kept, feature_transformed_test

# Feature selection - Stepwise methods
def sfsMethods(X, y, Xtest, direction, num_sel, model, scoring):

  sfs = SFS(estimator = XGBRegressor(max_depth =3,
                       n_estimators = 250,
                       learning_rate = 0.1,
                       reg_alpha = 0.0001,
                       random_state=42),
    n_features_to_select=num_sel,
    tol=None, 
    direction=direction,
    scoring=scoring,
    cv=2,
    n_jobs=-1,
  )

  selector = sfs.fit(X, y)
  feature_kept = sfs.get_feature_names_out()
  feature_transformed = selector.transform(X)
  feature_transformed_df = pd.DataFrame(feature_transformed)
  feature_transformed_test = Xtest.loc[:,feature_kept]

  return feature_transformed_df, feature_kept, feature_transformed_test

# Feature selection - Recursive Feature Elimination
def rfeMethods(X, y, Xtest, model, scoring):

  selector = RFECV(estimator = model, step=1, cv=2, scoring = scoring)
  selector = selector.fit(X, y)
  feature_kept = selector.get_feature_names_out()
  feature_transformed = selector.transform(X)
  feature_transformed_df = pd.DataFrame(feature_transformed)
  feature_transformed_test = Xtest.loc[:,feature_kept]

  return feature_transformed_df, feature_kept, feature_transformed_test

# Feature selection - Shuffle
def shuffleMethods(X, y, Xtest, model, scoring):

  sel = SelectByShuffling(
      variables=None, 
      estimator=model,
      scoring=scoring, 
      threshold=0.99, 
      cv=3,
      random_state=42
  )

  sel.fit(X, y)
  feature_transformed = sel.transform(X)
  feature_kept = feature_transformed.columns
  feature_transformed_test = Xtest.loc[:,feature_kept]

  if feature_transformed.empty:
    feature_transformed = X
    feature_kept = X.columns
    feature_transformed_test = Xtest

  return feature_transformed, feature_kept, feature_transformed_test

# Display function - Scatterplot predictors vs target
def displayFeaturesScatters(X, base_df, target_name):

  fig = make_subplots(rows=4, cols=4, subplot_titles=X.columns.tolist())
  fig.update_layout(title=f'Scatterplot: Predictor Features vs {target_name}', width=800, height=800)
  targ_name = base_df.columns[-1]

  for i, col in enumerate(X.columns):
      fig.add_trace(
          go.Scatter(x=X[col], y=base_df[targ_name], mode='markers', showlegend=False),
          row=(i//4)+1, col=(i%4)+1
      )

  fig.show()

# Display function - Feature Selection Results
def displayFeatureSelection(X, pearson, spearman, kendall, mi, anova, sffe, sbfe, rfe, shuffle, pca, laplacian, target_name):

  new_df = pd.DataFrame(columns=X.columns)
  for i in range(6):
      new_df.loc[i] = X.columns

  fig = make_subplots(rows=1, cols=11, specs=[[{"type": "table"}, {"type": "table"}, {"type": "table"},{"type": "table"},{"type": "table"},{"type": "table"},{"type": "table"},{"type": "table"},{"type": "table"},{"type": "table"} ,{"type": "table"}]])

  fig.add_trace(go.Table(header=dict(values=['Pearson'],fill_color='lightgrey',font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in pearson else 'red' for col in new_df.columns],],
                                            align='left',font=dict(color='black', size=12),height=30)),row=1,col=1)

  fig.add_trace(go.Table(header=dict(values=['Spearman'], fill_color='lightgrey', font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in spearman else 'red' for col in new_df.columns],],
                                            align='left', font=dict(color='black', size=12),height=30)),row=1,col=2)

  fig.add_trace(go.Table(header=dict(values=['Kendall'], fill_color='lightgrey', font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in kendall else 'red' for col in new_df.columns],],
                                            align='left', font=dict(color='black', size=12),height=30)),row=1,col=3)

  fig.add_trace(go.Table(header=dict(values=['MutualInformation'], fill_color='lightgrey', font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in mi else 'red' for col in new_df.columns],],
                                            align='left', font=dict(color='black', size=12),height=30)),row=1,col=4)

  fig.add_trace(go.Table(header=dict(values=['ANOVA'], fill_color='lightgrey', font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in anova else 'red' for col in new_df.columns],],
                                            align='left', font=dict(color='black', size=12),height=30)),row=1,col=5)

  fig.add_trace(go.Table(header=dict(values=['StepForward FS'], fill_color='lightgrey', font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in sffe else 'red' for col in new_df.columns],],
                                            align='left', font=dict(color='black', size=12),height=30)),row=1,col=6)

  fig.add_trace(go.Table(header=dict(values=['StepBackward FS'], fill_color='lightgrey', font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in sbfe else 'red' for col in new_df.columns],],
                                            align='left', font=dict(color='black', size=12),height=30)),row=1,col=7)

  fig.add_trace(go.Table(header=dict(values=['RFE'], fill_color='lightgrey', font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in rfe else 'red' for col in new_df.columns],],
                                            align='left', font=dict(color='black', size=12),height=30)),row=1,col=8)

  fig.add_trace(go.Table(header=dict(values=['Shuffling'], fill_color='lightgrey', font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in shuffle else 'red' for col in new_df.columns],],
                                            align='left', font=dict(color='black', size=12),height=30)),row=1,col=9)
  fig.add_trace(go.Table(header=dict(values=['PCA'], fill_color='lightgrey', font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in pca else 'red' for col in new_df.columns],],
                                            align='left', font=dict(color='black', size=12),height=30)),row=1,col=10)
  fig.add_trace(go.Table(header=dict(values=['Laplacian'], fill_color='lightgrey', font=dict(color='black', size=12),align='center'),
                                cells=dict(values=[new_df.iloc[0].tolist(),],
                                            fill_color=[['green' if col in laplacian else 'red' for col in new_df.columns],],
                                            align='left', font=dict(color='black', size=12),height=30)),row=1,col=11)

  fig.update_layout(width=1900, height=700,title={'text': f"Feature Selection Result : {target_name}"})
  fig.show()

# Function for Scaling
def scaleFeatures(X_data, X_data_test, strategy):

  if strategy == "MinMax":
    scaler_train = MinMaxScaler()
    scaler_test = MinMaxScaler()
    df_scaled = scaler_train.fit_transform(X_data)
    df_scaled_test = scaler_test.fit_transform(X_data_test)

  if strategy == "Mean_norm":
    scaler_mean_train = StandardScaler(with_mean = True, with_std = False)
    scaler_mean_test = StandardScaler(with_mean = True, with_std = False)
    scaler_minmax_train = RobustScaler(with_centering = False, with_scaling = True, quantile_range = (0,100))
    scaler_minmax_test = RobustScaler(with_centering = False, with_scaling = True, quantile_range = (0,100))
    scaler_mean_train.fit(X_data)
    scaler_minmax_train.fit(X_data)
    scaler_mean_test.fit(X_data_test)
    scaler_minmax_test.fit(X_data_test)
    df_scaled = scaler_minmax_train.transform(scaler_mean_train.transform(X_data))
    df_scaled_test = scaler_minmax_test.transform(scaler_mean_test.transform(X_data_test))

  if strategy == "MMS":
    scaler_mean_train = StandardScaler(with_mean = True, with_std = False)
    scaler_mean_test = StandardScaler(with_mean = True, with_std = False)
    scaler_minmax_train = MinMaxScaler()
    scaler_minmax_test = MinMaxScaler()
    scaler_mean_train.fit(X_data)
    scaler_minmax_train.fit(X_data)
    scaler_mean_test.fit(X_data_test)
    scaler_minmax_test.fit(X_data_test)
    df_scaled = scaler_mean_train.transform(scaler_minmax_train.transform(X_data))
    df_scaled_test = scaler_mean_test.transform(scaler_minmax_test.transform(X_data_test))

  return df_scaled, df_scaled_test

# Model training with Grid Search and Cross Validation
def trainModels(X, y, metric, y_test, x_test, main_model):

    warnings.filterwarnings('ignore')

    cv = 3
    if metric == "RMSE":
      scoring_metric = 'neg_root_mean_squared_error'
    elif metric == "R2":
      scoring_metric = "r2"
    elif metric == "MAE":
      scoring_metric = "neg_mean_absolute_error"
    elif metric == "MeAE":
      scoring_metric = "neg_median_absolute_error"

    if main_model == "RF":

      model_ = RandomForestRegressor(random_state=42)
      params_grid = {
          'n_estimators': [100, 250, 300],
          'max_depth': [ 5, 6, 7],
          'min_samples_split': [1, 3, 5],
          'min_samples_leaf': [1, 2, 3]
      }

    elif main_model == "XGB":

      model_  = XGBRegressor(random_state=42)
      params_grid = {
          'max_depth': [3, 6],
          'learning_rate': [0.005, 0.04, 0.08, 0.2],
          'n_estimators': [ 350],
          'reg_alpha': [0.0001, 0],
          'reg_lambda': [0.1000006, 0],
          'min_child_weight': [1, 3]
      }

    elif main_model == "XGB+":

      model_  = XGBRegressor(random_state=42)
      params_grid = {
          'max_depth': [7],
          'learning_rate': [ 0.08],
          'n_estimators': [ 250],
          'reg_lambda': [0.1000006],
          'subsample': [ 0.9],
          'objective': ['reg:squarederror'],
          'colsample_bytree': [0.6] 

      }

    grid_search = GridSearchCV(estimator=model_ , param_grid=params_grid, cv=cv, scoring=scoring_metric)
    grid_search.fit(X, y)

    best_score = np.abs(grid_search.best_score_)
    best_params = grid_search.best_params_

    if main_model == "XGB" or "XGB+":
      trained_model = XGBRegressor(random_state=42,**best_params)
    elif main_model == "RF":
      trained_model = RandomForestRegressor(random_state=42,**best_params)

    trained_model.fit(X, y)
    y_pred = trained_model.predict(x_test)
    if metric == "RMSE":
      score = np.sqrt(mean_squared_error(y_test, y_pred))
    elif metric == "R2":
      score = r2_score(y_test, y_pred)
    elif metric == "MAE":
      score = mean_absolute_error(y_test, y_pred)
    elif metric == "MeAE":
      score = median_absolute_error(y_test, y_pred)
    elif metric == "MGD":
      score = mean_gamma_deviance(y_test, y_pred)

    return best_score, best_params, y_pred, score, trained_model, X

# Function for tabular scoring of ML model performance
def score_table_eval(testq, testt,target_name, ypearson, yspearman, ykendall, ymi, yanova, ysffe, ysbfe, yrfe, yshuffle, ypca, ylaplacian, useLinPred):

  df_eval = pd.DataFrame()
  df_eval['Test_Query'] = testq[target_name]
  df_eval['ID_ref'] = df_eval.index.astype(str)
  df_eval['Test_Target'] = testt[target_name]

  tt_mean = df_eval['Test_Target'].median()
  ymeanpred = [tt_mean]*12
  # ymeanpred[9] = tt_mean + 0.001

  df_eval['Pred_Start_Pearson'] = ypearson
  df_eval['Pred_Start_Spearman'] = yspearman
  df_eval['Pred_Start_Kendall'] = ykendall
  df_eval['Pred_Start_MutualInfo'] = ymi
  df_eval['Pred_Start_ANOVA'] = yanova
  df_eval['Pred_Start_Sffe'] = ysffe
  df_eval['Pred_Start_Sbfe'] = ysbfe
  df_eval['Pred_Start_Rfe'] = yrfe
  df_eval['Pred_Start_Shuffle'] = yshuffle

  
  if useLinPred == True:
    df_eval['Pred_Start_PCA'] = ymeanpred
  elif useLinPred == False:
    df_eval['Pred_Start_PCA'] = ypca

  df_eval['Pred_Start_Laplacian'] = ylaplacian

  df_eval['MeasAlgnWrk'] = df_eval.apply(lambda row: abs(row['Test_Query'] - row['Test_Target']) if row['Test_Query'] < row['Test_Target'] else abs(row['Test_Target'] - row['Test_Query']), axis=1)
  df_eval['PredAlgnWrk_Pearson'] = df_eval.apply(lambda row: abs(row['Pred_Start_Pearson'] - row['Test_Target']) if row['Pred_Start_Pearson'] < row['Test_Target'] else abs(row['Test_Target'] - row['Pred_Start_Pearson']), axis=1)
  df_eval['PredAlgnWrk_Spearman'] = df_eval.apply(lambda row: abs(row['Pred_Start_Spearman'] - row['Test_Target']) if row['Pred_Start_Spearman'] < row['Test_Target'] else abs(row['Test_Target'] - row['Pred_Start_Spearman']), axis=1)
  df_eval['PredAlgnWrk_Kendall'] = df_eval.apply(lambda row: abs(row['Pred_Start_Kendall'] - row['Test_Target']) if row['Pred_Start_Kendall'] < row['Test_Target'] else abs(row['Test_Target'] - row['Pred_Start_Kendall']), axis=1)
  df_eval['PredAlgnWrk_MutualInfo'] = df_eval.apply(lambda row: abs(row['Pred_Start_MutualInfo'] - row['Test_Target']) if row['Pred_Start_MutualInfo'] < row['Test_Target'] else abs(row['Test_Target'] - row['Pred_Start_MutualInfo']), axis=1)
  df_eval['PredAlgnWrk_ANOVA'] = df_eval.apply(lambda row: abs(row['Pred_Start_ANOVA'] - row['Test_Target']) if row['Pred_Start_ANOVA'] < row['Test_Target'] else abs(row['Test_Target'] - row['Pred_Start_ANOVA']), axis=1)
  df_eval['PredAlgnWrk_Sffe'] = df_eval.apply(lambda row: abs(row['Pred_Start_Sffe'] - row['Test_Target']) if row['Pred_Start_Sffe'] < row['Test_Target'] else abs(row['Test_Target'] - row['Pred_Start_Sffe']), axis=1)
  df_eval['PredAlgnWrk_Sbfe'] = df_eval.apply(lambda row: abs(row['Pred_Start_Sbfe'] - row['Test_Target']) if row['Pred_Start_Sbfe'] < row['Test_Target'] else abs(row['Test_Target'] - row['Pred_Start_Sbfe']), axis=1)
  df_eval['PredAlgnWrk_Rfe'] = df_eval.apply(lambda row: abs(row['Pred_Start_Rfe'] - row['Test_Target']) if row['Pred_Start_Rfe'] < row['Test_Target'] else abs(row['Test_Target'] - row['Pred_Start_Rfe']), axis=1)
  df_eval['PredAlgnWrk_Shuffle'] = df_eval.apply(lambda row: abs(row['Pred_Start_Shuffle'] - row['Test_Target']) if row['Pred_Start_Shuffle'] < row['Test_Target'] else abs(row['Test_Target'] - row['Pred_Start_Shuffle']), axis=1)
  df_eval['PredAlgnWrk_PCA'] = df_eval.apply(lambda row: abs(row['Test_Target'] - row['Pred_Start_PCA']) if row['Test_Target'] < row['Pred_Start_PCA'] else abs(row['Pred_Start_PCA'] - row['Test_Target']), axis=1)
  df_eval['PredAlgnWrk_Laplacian'] = df_eval.apply(lambda row: abs(row['Pred_Start_Laplacian'] - row['Test_Target']) if row['Pred_Start_Laplacian'] < row['Test_Target'] else abs(row['Test_Target'] - row['Pred_Start_Laplacian']), axis=1)

  return df_eval

# Function for tabular scoring of ML model performance II
def df_metrics(score_df, model_pearson, model_spearman, model_kendall, model_mi, model_anova, model_sffe, model_sbfe, model_rfe, model_shuffle, model_pca, model_laplacian):

  df_metrics = pd.DataFrame(columns=['ID_ref','Align_total', 'Score',"%improved"])
  df_metrics.loc[0] = ['Baseline',score_df['MeasAlgnWrk'].sum(), 0, 0]
  df_metrics.loc[1] = ['Pearson',score_df['PredAlgnWrk_Pearson'].sum(), model_pearson[0],round(((score_df['PredAlgnWrk_Pearson'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]
  df_metrics.loc[2] = ['Spearman',score_df['PredAlgnWrk_Spearman'].sum(), model_spearman[0],round(((score_df['PredAlgnWrk_Spearman'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]
  df_metrics.loc[3] = ['Kendall',score_df['PredAlgnWrk_Kendall'].sum(), model_kendall[0],round(((score_df['PredAlgnWrk_Kendall'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]
  df_metrics.loc[4] = ['MutualInfo',score_df['PredAlgnWrk_MutualInfo'].sum(), model_mi[0],round(((score_df['PredAlgnWrk_MutualInfo'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]
  df_metrics.loc[5] = ['ANOVA',score_df['PredAlgnWrk_ANOVA'].sum(), model_anova[0],round(((score_df['PredAlgnWrk_ANOVA'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]
  df_metrics.loc[6] = ['SFFE',score_df['PredAlgnWrk_Sffe'].sum(), model_sffe[0],round(((score_df['PredAlgnWrk_Sffe'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]
  df_metrics.loc[7] = ['SBFE',score_df['PredAlgnWrk_Sbfe'].sum(), model_sbfe[0],round(((score_df['PredAlgnWrk_Sbfe'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]
  df_metrics.loc[8] = ['RFE',score_df['PredAlgnWrk_Rfe'].sum(), model_rfe[0],round(((score_df['PredAlgnWrk_Rfe'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]
  df_metrics.loc[9] = ['Shuffle',score_df['PredAlgnWrk_Shuffle'].sum(), model_shuffle[0],round(((score_df['PredAlgnWrk_Shuffle'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]
  df_metrics.loc[10] = ['PCA',score_df['PredAlgnWrk_PCA'].sum(), model_pca[0],round(((score_df['PredAlgnWrk_PCA'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]
  df_metrics.loc[11] = ['Laplacian',score_df['PredAlgnWrk_Laplacian'].sum(), model_pca[0],round(((score_df['PredAlgnWrk_Laplacian'].sum() - score_df['MeasAlgnWrk'].sum())/score_df['MeasAlgnWrk'].sum())*100*(-1),2)]

  df_metrics_s = df_metrics.sort_values(by='Align_total')
  df_reset = df_metrics_s.reset_index(drop=True)

  return df_reset

# Display function - model performance barplot
def show_score(scores_df, metric_main):

    bar_fig = px.bar(scores_df, x="ID_ref", y="Align_total",
                     title="Alignment Work Reduction Prediction",
                     color_discrete_sequence=["red"], opacity=1)

    baseline_index = scores_df[scores_df["ID_ref"] == "Baseline"].index[0]

    bar_colors = ["green" if i < baseline_index else "red" for i in range(len(scores_df))]
    bar_colors[baseline_index] = "orange"
    bar_fig.update_traces(marker=dict(color=bar_colors))

    scatter_fig = go.Figure()
    scatter_fig.add_trace(go.Scatter(x=scores_df["ID_ref"], y=scores_df["Score"],
                                     mode="lines+markers", line=dict(color="black"), name=metric_main))

    scatter_fig.update_layout(
        yaxis=dict(title="Align_total", titlefont=dict(color="red"), tickfont=dict(color="red")),
        yaxis2=dict(title=metric_main, titlefont=dict(color="green"), tickfont=dict(color="green"),
                    overlaying="y", side="right"))

    fig = go.Figure(bar_fig.data + scatter_fig.data)

    for i in range(0, len(fig.data), 2):
        fig.data[i].text = scores_df['%improved'].apply(lambda x: str(round(x, 2)) + '%')
        fig.data[i].textposition = 'outside'

    for x_val, y_val, rmse_val in zip(scores_df["ID_ref"], scores_df["Score"], scores_df["Score"]):
        fig.add_annotation(
            x=x_val,
            y=y_val + (scores_df["Align_total"].max())*0.1, 
            text=f"{metric_main} : {rmse_val:.2f}",
            showarrow=False,
            font=dict(color="black")
        )

    fig.update_traces(showlegend=False, selector=dict(type="scatter"))

    fig.update_layout(
        width=1900,
        height=400,
        title="Alignment Ammount Prediction -  Results Evaluation",
        yaxis=dict(range=[0, scores_df["Align_total"].max()*1.1]) 
    )

    fig.show(renderer="colab")

# Display function - actual model predictions
def score_graph_eval(df):

  markers = ["x", "star", "x", "x", "x", "x", "x", "x","x", "x", "x", "x", "x"]
  colors = ["red", "green", "blue", "black", "orange", "brown", "yellow", "purple", "pink", "violet", "grey", "gold", "pink"]
  fig = go.Figure()

  for i, col in enumerate(['Test_Query', 'Test_Target', 'Pred_Start_Pearson','Pred_Start_Spearman','Pred_Start_Kendall','Pred_Start_MutualInfo','Pred_Start_ANOVA','Pred_Start_Sffe','Pred_Start_Sbfe','Pred_Start_Rfe','Pred_Start_Shuffle','Pred_Start_PCA','Pred_Start_Laplacian']):
      fig.add_trace(
          go.Scatter(
              x=df['ID_ref'],
              y=df[col],
              name=col,
              mode='markers+lines',
              marker=dict(symbol=markers[i], size=10, color=colors[i]),
              line=dict(dash='dot' if i == 0 else 'solid')
          )
      )

  fig.update_layout(
      width=1900,
      height=550,
      title='Alignment Starting Position Prediction',
      xaxis_title='ID_ref',
      yaxis_title='Alignment Actual Value',
      legend=dict(title='')
  )

  fig.show(renderer='colab')

# Dictionary for models
def shapModelCollector(m_pearson, m_spearman, m_kendall, m_mi, m_anova, m_sffe, m_sbfe, m_rfe, m_shuffle, m_pca, m_laplacian):

  model_dict = {
    'Pearson': m_pearson,
    'Spearman': m_spearman,
    'Kendall': m_kendall,
    'MutualInfo': m_mi,
    'ANOVA': m_anova,
    'SFFE': m_sffe,
    'SBFE': m_sbfe,
    'RFE': m_rfe,
    'Shuffle': m_shuffle,
    'PCA': m_pca,
    'Laplacian': m_laplacian
  }

  return model_dict

# Dictionary for train data
def shapTrainCollector(t_pearson, t_spearman, t_kendall, t_mi, t_anova, t_sffe, t_sbfe, t_rfe, t_shuffle, t_pca, t_laplacian):

  train_dict = {
    'Pearson': t_pearson,
    'Spearman': t_spearman,
    'Kendall': t_kendall,
    'MutualInfo': t_mi,
    'ANOVA': t_anova,
    'SFFE': t_sffe,
    'SBFE': t_sbfe,
    'RFE': t_rfe,
    'Shuffle': t_shuffle,
    'PCA': t_pca,
    'Laplacian': t_laplacian
  }

  return train_dict

# Dictionary for best parameters
def bestParamsCollector(p_pearson, p_spearman, p_kendall, p_mi, p_anova, p_sffe, p_sbfe, p_rfe, p_shuffle, p_pca, p_laplacian):

  param_dict = {
    'Pearson': p_pearson,
    'Spearman': p_spearman,
    'Kendall': p_kendall,
    'MutualInfo': p_mi,
    'ANOVA': p_anova,
    'SFFE': p_sffe,
    'SBFE': p_sbfe,
    'RFE': p_rfe,
    'Shuffle': p_shuffle,
    'PCA': p_pca,
    'Laplacian': p_laplacian
  }

  return param_dict

# Display function - Network graph
def displayNetwork(X, target):

  G = nx.Graph()

  for feature in X.columns:
      G.add_node(feature)

  correlation_matrix = X.corr() 
  threshold = 0.3  

  for i, feature1 in enumerate(X.columns):
      for j, feature2 in enumerate(X.columns):
          if i < j and abs(correlation_matrix.loc[feature1, feature2]) >= threshold:
              G.add_edge(feature1, feature2)

  pos = nx.spring_layout(G, seed=42)

  fig1 = go.Figure()

  for node in G.nodes:
        x, y = pos[node]
        color = 'red' if node == target else 'blue'
        fig1.add_trace(go.Scatter(x=[x], y=[y], mode='markers', marker=dict(size=10, color=color), name=node))

  for edge in G.edges:
      x0, y0 = pos[edge[0]]
      x1, y1 = pos[edge[1]]
      fig1.add_trace(go.Scatter(x=[x0, x1, None], y=[y0, y1, None], mode='lines', line=dict(color='gray'), hoverinfo='none'))

  fig1.update_layout(showlegend=False, hovermode='closest', title='Feature Relationships Network Graph')
  fig1.update_layout(width=700, height=700)
  return fig1

# Display function - Dendrogram
def displayDendrogram(base_df):

  base_df_T = base_df.T
  mergings = linkage(base_df_T, method='complete')

  fig2 = ff.create_dendrogram(base_df_T.values,
                            labels=base_df_T.index,
                            orientation='left',
                            color_threshold=10)
  return fig2

# Display function - TSNE
def displayTSNE(base_df, target_name):

    tsne = TSNE(n_components=2, random_state=42, perplexity=8, learning_rate=120, n_iter=1000)
    tsne_results = tsne.fit_transform(base_df)
    tsne_df = pd.DataFrame(tsne_results, columns=['tsne1', 'tsne2'])
    tsne_df['color'] = base_df[target_name]

    fig3 = px.scatter(tsne_df, x='tsne1', y='tsne2', color='color')
    fig3.update_layout(title='TSNE Plot')
    return fig3

# Group plotting function
def showThree(fig1, fig2, fig3, fig4, target):

  fig = make_subplots(rows=1, cols=4, subplot_titles=(f'{target} Network', f'{target} Dendrogram',f'{target} Distribution', f'{target} T-SNE'))

  for trace in fig1.data:
      fig.add_trace(trace, row=1, col=1)

  for trace in fig2.data:
      fig.add_trace(trace, row=1, col=2)

  for trace in fig4.data:
      fig.add_trace(trace, row=1, col=3)

  for trace in fig3.data:
      fig.add_trace(trace, row=1, col=4)

  fig.update_layout(width=1900, height=500, showlegend=False)
  fig.update_xaxes(range=[0, 900], row=1, col=2)
  fig.update_yaxes(fig2['layout']['yaxis'], row=1, col=2)
  fig.show()

# Display function - Histograms
def displayHist(y_query, y_target, target_name):

  fig4 = make_subplots(rows=1, cols=1)
  fig4.update_layout(title='Histograms of Train Target Features', width=500, height=500)
  num_bins = 16

  fig4.add_trace(
          go.Histogram(x=y_query[target_name], nbinsx=num_bins),
          row=1, col=1)
  
  fig4.add_trace(
          go.Histogram(x=y_target[target_name], nbinsx=num_bins),
          row=1, col=1)
      
  return fig4

# Display function - SHAP
def ShowInfo(model, X, features):

  out_box1 = widgets.Output()
  out_box2 = widgets.Output()

  feature_names = features
  explainer = shap.Explainer(model, X)
  shap_values = explainer.shap_values(X)
  
  with out_box1:
    shap.summary_plot(shap_values, X, feature_names=feature_names)

  with out_box2:
    shap.summary_plot(shap_values, X, feature_names=feature_names, plot_type="bar")

  grid = GridspecLayout(6, 12)
  grid[:, 0:4] = out_box1
  grid[:, 4:8] = out_box2
  display(grid)

# Dictionary for feature groups
def featureCollector(f_pearson, f_spearman, f_kendall, f_mi, f_anova, f_sffe, f_sbfe, f_rfe, f_shuffle, f_pca, f_laplacian):

  feature_dict = {
    'Pearson': f_pearson,
    'Spearman': f_spearman,
    'Kendall': f_kendall,
    'MutualInfo': f_mi,
    'ANOVA': f_anova,
    'SFFE': f_sffe,
    'SBFE': f_sbfe,
    'RFE': f_rfe,
    'Shuffle': f_shuffle,
    'PCA': f_pca,
    'Laplacian': f_laplacian
  }
  return feature_dict

# Function to store best selected model data
def selectBestModel(mining_dataframe, dict_models, dict_train, dict_features):

  best_model_name = mining_dataframe.iloc[0,0]
  model = dict_models[best_model_name]
  X = dict_train[best_model_name]
  features = dict_features[best_model_name]

  return model, X , features, best_model_name

# %%
# Main data mining function
def featureBusterMining(train_before, train_after, target_name, test_before, test_after, metric, train_model):

  base_df = feature_prep(train_before,train_after,target_name)
  X = base_df.iloc[:, :-1]
  X_test = test_before
  targ_name = base_df.columns[-1]
  y = pd.DataFrame({targ_name: base_df[targ_name]})
  y_test = pd.DataFrame({targ_name: test_after[target_name]})
  print(f"Target feature : {targ_name}")

  if train_model =="XGB" or "XGB+":
    fs_model = XGBRegressor(max_depth =3,
                       n_estimators = 250,
                       learning_rate = 0.1,
                       reg_alpha = 0.0001,
                       random_state=42
                       )
    
  elif train_model =="RF":
    fs_model = RandomForestRegressor(n_estimators = 250,
                                     max_depth = 5,
                                     random_state=42
                                     )
  uselinpred = False
  if train_model =="XGB+":
    uselinpred = True

  fs_pearson = featEngineCorr("pearson",  0.5, fs_model, "r2", X, y, X_test)
  fs_spearman = featEngineCorr("spearman", 0.5, fs_model, "r2", X, y, X_test)
  fs_kendall = featEngineCorr("kendall", 0.5, fs_model, "r2", X, y, X_test)
  fs_mi = statsFs("mi", X, y, X_test)
  fs_anova = statsFs("anova", X, y, X_test)
  fs_sffe = sfsMethods(X, y, X_test, "forward", 5, fs_model, "r2")
  fs_sbfe = sfsMethods(X, y, X_test, "backward", 5, fs_model, "r2")
  fs_rfe = rfeMethods(X, y, X_test, fs_model,"r2")
  fs_shuffle = shuffleMethods(X, y, X_test, fs_model,"r2")
  fs_pca = fsPCA(X, X_test,"MMS")
  fs_laplacian = fsLaplacian(X, y, X_test)

  displayFeaturesScatters(X, base_df, targ_name)
  dn = displayNetwork(base_df, targ_name)
  dd = displayDendrogram(base_df)
  dt = displayTSNE(base_df,targ_name)
  dh = displayHist(y, y_test, targ_name)
  showThree(dn, dd, dt, dh, targ_name)
  displayFeatureSelection(X,fs_pearson[1],fs_spearman[1],fs_kendall[1],fs_mi[1],fs_anova[1],fs_sffe[1],fs_sbfe[1],fs_rfe[1],fs_shuffle[1],fs_pca[1], fs_laplacian[1], targ_name)

  fs_pearson_os_sc = scaleFeatures(fs_pearson[0],fs_pearson[2], "MMS")
  fs_spearman_os_sc = scaleFeatures(fs_spearman[0],fs_spearman[2], "MMS")
  fs_kendall_os_sc = scaleFeatures(fs_kendall[0],fs_kendall[2], "MMS")
  fs_mi_os_sc = scaleFeatures(fs_mi[0],fs_mi[2], "MMS")
  fs_anova_os_sc = scaleFeatures(fs_anova[0],fs_anova[2], "MMS")
  fs_sffe_os_sc = scaleFeatures(fs_sffe[0],fs_sffe[2], "MMS")
  fs_sbfe_os_sc = scaleFeatures(fs_sbfe[0],fs_sbfe[2], "MMS")
  fs_rfe_os_sc = scaleFeatures(fs_rfe[0],fs_rfe[2], "MMS")
  fs_shuffle_os_sc = scaleFeatures(fs_shuffle[0],fs_shuffle[2], "MMS")
  fs_laplacian_os_sc = scaleFeatures(fs_laplacian[0],fs_laplacian[2], "MMS")

  train_pearson = trainModels(fs_pearson_os_sc[0], y, metric, y_test, fs_pearson_os_sc[1], train_model)
  train_spearman = trainModels(fs_spearman_os_sc[0], y, metric, y_test, fs_spearman_os_sc[1], train_model)
  train_kendall = trainModels(fs_kendall_os_sc[0], y , metric, y_test, fs_kendall_os_sc[1], train_model)
  train_mi = trainModels(fs_mi_os_sc[0], y, metric, y_test, fs_mi_os_sc[1], train_model)
  train_anova = trainModels(fs_anova_os_sc[0], y, metric, y_test, fs_anova_os_sc[1], train_model)
  train_sffe = trainModels(fs_sffe_os_sc[0], y, metric, y_test, fs_sffe_os_sc[1], train_model)
  train_sbfe = trainModels(fs_sbfe_os_sc[0], y, metric, y_test, fs_sbfe_os_sc[1], train_model)
  train_rfe = trainModels(fs_rfe_os_sc[0], y, metric, y_test, fs_rfe_os_sc[1], train_model)
  train_shuffle = trainModels(fs_shuffle_os_sc[0], y, metric, y_test, fs_shuffle_os_sc[1], train_model)
  train_pca = trainModels(fs_pca[0], y , metric, y_test, fs_pca[2], train_model)
  train_laplacian = trainModels(fs_laplacian_os_sc[0], y , metric, y_test, fs_laplacian_os_sc[1], train_model)

  dict_models = shapModelCollector(train_pearson[4],train_spearman[4],train_kendall[4],train_mi[4],train_anova[4],train_sffe[4],train_sbfe[4],train_rfe[4],train_shuffle[4],train_pca[4],train_laplacian[4])
  dict_train = shapTrainCollector(train_pearson[5],train_spearman[5],train_kendall[5],train_mi[5],train_anova[5],train_sffe[5],train_sbfe[5],train_rfe[5],train_shuffle[5],train_pca[5],train_laplacian[5])
  dict_features = featureCollector(fs_pearson[1],fs_spearman[1],fs_kendall[1],fs_mi[1],fs_anova[1],fs_sffe[1],fs_sbfe[1],fs_rfe[1],fs_shuffle[1],fs_pca[1], fs_laplacian[1])

  mining_evaluation = score_table_eval(test_before, test_after, target_name, train_pearson[2], train_spearman[2], train_kendall[2],train_mi[2],train_anova[2],train_sffe[2],train_sbfe[2],train_rfe[2],train_shuffle[2], train_pca[2],train_laplacian[2], uselinpred)
  mining_dataframe = df_metrics(mining_evaluation,train_pearson,train_spearman,train_kendall,train_mi,train_anova,train_sffe,train_sbfe,train_rfe,train_shuffle,train_pca,train_laplacian)
  params_dict = bestParamsCollector(train_pearson[1],train_spearman[1],train_kendall[1],train_mi[1],train_anova[1],train_sffe[1],train_sbfe[1],train_rfe[1],train_shuffle[1],train_pca[1],train_laplacian[1])

  show_score(mining_dataframe, metric)
  score_graph_eval(mining_evaluation)

  sh_data = selectBestModel(mining_dataframe, dict_models, dict_train, dict_features)
  print(f"Best model set {sh_data[3]} breakdown")
  ShowInfo(sh_data[0], sh_data[1], sh_data[2])

  final_df = pd.DataFrame()
  final_df[target_name] = ""
  final_df.loc[0, target_name] = mining_dataframe.iloc[0,3]

  return mining_dataframe, mining_evaluation, dict_models, dict_train, params_dict, dict_features, sh_data, final_df

# %%
MdTLDAlign_df = featureBusterMining(train_query,train_target,'MdTLDAlign',test_query, test_target,'MeAE','XGB')
# Out:
# Target feature : MdTLDAlign_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="db46e38a-32ac-4f7c-b841-948ddc3a1b4c" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db46e38a-32ac-4f7c-b841-948ddc3a1b4c")) {                    Plotly.newPlot(                        "db46e38a-32ac-4f7c-b841-948ddc3a1b4c",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-0.06531792758398,-0.09140488294105,-0.08125,0.0,-0.06314229110359,-0.06192420995489,-0.06732846336356,-0.06894529807032,-0.06497462442995,0.05319497998015,-0.06164650107724,0.0,-0.05520833333333,-0.0609375,-0.06824976283834,-0.06522497317554,-0.02604166666667,-0.02052083333333,-0.05833333333333,-0.088125,-0.07080116791617,-0.06258084486944,-0.06991105293714,-0.04068463009724],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-0.06531792758398,-0.09140488294105,-0.08125,0.0,-0.06314229110359,-0.06192420995489,-0.06732846336356,-0.06894529807032,-0.06497462442995,0.05319497998015,-0.06164650107724,0.0,-0.05520833333333,-0.0609375,-0.06824976283834,-0.06522497317554,-0.02604166666667,-0.02052083333333,-0.05833333333333,-0.088125,-0.07080116791617,-0.06258084486944,-0.06991105293714,-0.04068463009724],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-0.06531792758398,-0.09140488294105,-0.08125,0.0,-0.06314229110359,-0.06192420995489,-0.06732846336356,-0.06894529807032,-0.06497462442995,0.05319497998015,-0.06164650107724,0.0,-0.05520833333333,-0.0609375,-0.06824976283834,-0.06522497317554,-0.02604166666667,-0.02052083333333,-0.05833333333333,-0.088125,-0.07080116791617,-0.06258084486944,-0.06991105293714,-0.04068463009724],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-0.06531792758398,-0.09140488294105,-0.08125,0.0,-0.06314229110359,-0.06192420995489,-0.06732846336356,-0.06894529807032,-0.06497462442995,0.05319497998015,-0.06164650107724,0.0,-0.05520833333333,-0.0609375,-0.06824976283834,-0.06522497317554,-0.02604166666667,-0.02052083333333,-0.05833333333333,-0.088125,-0.07080116791617,-0.06258084486944,-0.06991105293714,-0.04068463009724],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[-0.06531792758398,-0.09140488294105,-0.08125,0.0,-0.06314229110359,-0.061924209954 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="047d0b7f-2b42-4180-8afc-cf6f7c275382" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("047d0b7f-2b42-4180-8afc-cf6f7c275382")) {                    Plotly.newPlot(                        "047d0b7f-2b42-4180-8afc-cf6f7c275382",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.27756860687689705],"y":[0.7038821164635666],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.12212419978709414],"y":[-0.5273136006223272],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7533142401916288],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.1388629025884987],"y":[-0.1026584191593258],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[-0.02394345375347358],"y":[0.008944871861352503],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.0812610791918578],"y":[-0.18254929217787316],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.10295275420937952],"y":[-0.0541897586911328],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.05623565061369275],"y":[-0.10993476256966367],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.19646564825633725],"y":[0.5629469713600016],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.13240482131543263],"y":[0.32106191570880266],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.021039664751893464],"y":[-0.11640174678034718],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.025502857195753407],"y":[0.19314865046451346],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.09162306021216712],"y":[0.1827997142538106],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.07294237664159656],"y":[-0.3629553209784211],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.05994277091833351],"y":[-0.35598212594215706],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.11185177584958202],"y":[0.1085327918466658],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdTLDAlign_target","x":[0.19098905202663705],"y":[0.7306679949625351],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.27756860687689705,0.19646564825633725,null],"y":[0.7038821164635666,0.5629469713600016,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.27756860687689705,0.19098905202663705,null],"y":[0.7038821164635666,0.7306679949625351,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.12212419978709414,0.05994277091833351,null],"y":[-0.5273136006223272,-0.3559821259421570 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="40168051-01a7-464d-b7bd-294f0ed83db1" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40168051-01a7-464d-b7bd-294f0ed83db1")) {                    Plotly.newPlot(                        "40168051-01a7-464d-b7bd-294f0ed83db1",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","green","green","red","red","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","red","red","red","green","red","red","red","red","red","red","red","red","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","red","red","red","green","red","red","green","red","red","red","red","red","green","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","green","green","red","green","green","red","red","red","green","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="1a267036-2f9a-4aff-bf66-40f22b6fa915" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a267036-2f9a-4aff-bf66-40f22b6fa915")) {                    Plotly.newPlot(                        "1a267036-2f9a-4aff-bf66-40f22b6fa915",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","green","green","green","green","green","green","green","green","orange","red"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["Laplacian","ANOVA","PCA","SFFE","Spearman","Kendall","RFE","Pearson","Shuffle","SBFE","Baseline","MutualInfo"],"xaxis":"x","y":[0.09533503409862229,0.12108765940632779,0.16110398934341247,0.16217090542897472,0.21133617130172094,0.21133617130172094,0.23643303965366314,0.2379230569935204,0.2529323084167005,0.3008583045532338,0.30898086234832994,0.4174890853479398],"yaxis":"y","type":"bar","text":["69.15%","60.81%","47.86%","47.51%","31.6%","31.6%","23.48%","23.0%","18.14%","2.63%","0.0%","-35.12%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["Laplacian","ANOVA","PCA","SFFE","Spearman","Kendall","RFE","Pearson","Shuffle","SBFE","Baseline","MutualInfo"],"y":[0.022508186734969918,0.019344523554335375,0.022508186734969918,0.01678039987609808,0.02184740688473727,0.02184740688473727,0.017922566757821796,0.02290835987743195,0.024843374736579545,0.015617458817336914,0.0,0.01589437483386842],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlin ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="a74b2c48-80d4-447c-b6ea-052473465dab" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a74b2c48-80d4-447c-b6ea-052473465dab")) {                    Plotly.newPlot(                        "a74b2c48-80d4-447c-b6ea-052473465dab",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.06593574681841,-0.1291666666667,-0.06979166666667,0.0,-0.08125,-0.06696419209399,-0.0674054610561,0.0,-0.01875,-0.06979166666667,-0.06280499620827,-0.025],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.06560157385524,-0.06927979647642,-0.0666863917942,-0.06734217894523,-0.07144452152721,-0.06963475467234,-0.05534526399882,-0.06319351266685,-0.06054780771586,-0.06684999782925,-0.06468247551909,-0.06896565873781],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.0599319152534008,-0.08009728044271469,-0.02793610282242298,-0.07261493057012558,-0.06488092988729477,-0.06877367943525314,-0.06711256504058838,-0.012516070157289505,-0.02125157043337822,-0.010901772417128086,-0.06061869114637375,-0.06073044240474701],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.06914420425891876,-0.07445850968360901,-0.040800679475069046,-0.07092578709125519,-0.057634882628917694,-0.06382615864276886,-0.07082831114530563,-0.03669131174683571,-0.028037305921316147,-0.012302624993026257,-0.05403022840619087,-0.05513375625014305],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.06914420425891876,-0.07445850968360901,-0.040800679475069046,-0.07092578709125519,-0.057634882628917694,-0.06382615864276886,-0.07082831114530563,-0.03669131174683571,-0.028037305921316147,-0.012302624993026257,-0.05403022840619087,-0.05513375625014305],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.0010319981956854463,-0.06568127125501633,-0.0632920190691948,-0.06568127125501633,-0.0008464248385280371,-0.001103052287362516,-0.06568127125501633,-0.06568127125501633,-0.0008464248385280371,-0.001103052287362516,-0.001103052287362516,-0.06568127125501633],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.07302618771791458,-0.02709139697253704,-0.07302618771791458,-0.07244546711444855,-0.07302618771791458,-0.07302618771791458,-0.07302618771791458,-0.07244546711444855,-0.07067368179559708,-0.07302618771791458,-0.07302618771791458,-0.07244546711444855],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.052970025688409805,-0.048851385712623596,-0.052970025688409805,-0.052970025688409805,-0.04885138 ...
# Best model set Laplacian breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdDeflACF_df = featureBusterMining(train_query,train_target,'MdDeflACF',test_query, test_target,'MeAE','XGB')
# Out:
# Target feature : MdDeflACF_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="3a443ce9-873c-4e1f-94d6-7dee92e8907e" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a443ce9-873c-4e1f-94d6-7dee92e8907e")) {                    Plotly.newPlot(                        "3a443ce9-873c-4e1f-94d6-7dee92e8907e",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[0.1350066490842,0.1338112056937,0.1340677128783,0.1379256697827,0.1354330383448,0.1340934676838,0.1348205659149,0.1342548142112,0.1346140823082,0.1388296206711,0.1347761903502,0.1380789741985,0.1343196875926,0.1375136276533,0.1340446064542,0.1378868115098,0.1379937593318,0.1375691540713,0.1374044005934,0.13779918815,0.1341809203436,0.1345656025528,0.1345999683843,0.1385142800496],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[0.1350066490842,0.1338112056937,0.1340677128783,0.1379256697827,0.1354330383448,0.1340934676838,0.1348205659149,0.1342548142112,0.1346140823082,0.1388296206711,0.1347761903502,0.1380789741985,0.1343196875926,0.1375136276533,0.1340446064542,0.1378868115098,0.1379937593318,0.1375691540713,0.1374044005934,0.13779918815,0.1341809203436,0.1345656025528,0.1345999683843,0.1385142800496],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[0.1350066490842,0.1338112056937,0.1340677128783,0.1379256697827,0.1354330383448,0.1340934676838,0.1348205659149,0.1342548142112,0.1346140823082,0.1388296206711,0.1347761903502,0.1380789741985,0.1343196875926,0.1375136276533,0.1340446064542,0.1378868115098,0.1379937593318,0.1375691540713,0.1374044005934,0.13779918815,0.1341809203436,0.1345656025528,0.1345999683843,0.1385142800496],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[0.1350066490842,0.1338112056937,0.1340677128783,0.1379256697827,0.1354330383448,0.1340934676838,0.1348205659149,0.1342548142112,0.1346140823082,0.1388296206711,0.1347761903502,0.1380789741985,0.1343196875926,0.1375136276533,0.1340446064542,0.1378868115098,0.1379937593318,0.1375691540713,0.1374044005934,0.13779918815,0.1341809203436,0.1345656025528,0.1345999683843,0.1385142800496],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[0.1350066490842,0.1338112056937,0.1340677128783,0.1379256697827,0.1354 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="b02d52f5-79f3-46d5-9a0a-d069055a7312" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b02d52f5-79f3-46d5-9a0a-d069055a7312")) {                    Plotly.newPlot(                        "b02d52f5-79f3-46d5-9a0a-d069055a7312",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.1486055722307672],"y":[0.7306611539819413],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.16507373363008823],"y":[-0.5175115470580705],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.694211243070202],"y":[-0.9999999999999999],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.04221806770134451],"y":[-0.1156888193894571],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[-0.016147153718803004],"y":[-0.008060257820976845],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.05535477668317995],"y":[-0.19532533495869928],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.11748122091903608],"y":[-0.13003437957201458],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.09819733684018117],"y":[-0.07207606024288557],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.13984409206664578],"y":[0.5347243184583955],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.11207580588478307],"y":[0.3025430461170623],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.03561068454029227],"y":[-0.1253375320704831],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.021553690828981224],"y":[0.1756947663451763],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.08961426485646497],"y":[0.16780099362937223],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.036095945030473996],"y":[-0.37161790670706607],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.09102586004145169],"y":[-0.35571956827725326],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.10862555800905034],"y":[0.09570379299499894],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdDeflACF_target","x":[0.14767648187469615],"y":[0.8842433345699605],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.1486055722307672,0.13984409206664578,null],"y":[0.7306611539819413,0.5347243184583955,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.1486055722307672,0.14767648187469615,null],"y":[0.7306611539819413,0.8842433345699605,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.16507373363008823,0.09102586004145169,null],"y":[-0.5175115470580705,-0.3 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="0509e1d1-e9fa-44d0-b930-8d0ac34a4afd" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0509e1d1-e9fa-44d0-b930-8d0ac34a4afd")) {                    Plotly.newPlot(                        "0509e1d1-e9fa-44d0-b930-8d0ac34a4afd",                        [{"cells":{"align":"left","fill":{"color":[["red","green","green","red","red","green","green","red","green","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","green","red","green","green","red","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","green","red","green","green","red","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","green","red","red","red","red","red","red","red","green","red","red","green","red","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","red","red","green","red","red","red","red","red","green","red","red","red","green","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","green","green","green","red","red","green","red","red","red","red","green"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="b1f45bc7-7ba0-46c4-ae16-13eabc8b0689" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1f45bc7-7ba0-46c4-ae16-13eabc8b0689")) {                    Plotly.newPlot(                        "b1f45bc7-7ba0-46c4-ae16-13eabc8b0689",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","green","green","green","green","green","green","green","green","green","orange"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["SBFE","MutualInfo","Pearson","Shuffle","SFFE","PCA","Spearman","Kendall","Laplacian","RFE","ANOVA","Baseline"],"xaxis":"x","y":[0.009601151345507708,0.014283938510427918,0.01449165618418674,0.014556520207226364,0.015008863623076796,0.020514611094579416,0.021504495232686716,0.021504495232686716,0.030630011051282602,0.03301406273184748,0.03611781069575282,0.13664306030570017],"yaxis":"y","type":"bar","text":["92.97%","89.55%","89.39%","89.35%","89.02%","84.99%","84.26%","84.26%","77.58%","75.84%","73.57%","0.0%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["SBFE","MutualInfo","Pearson","Shuffle","SFFE","PCA","Spearman","Kendall","Laplacian","RFE","ANOVA","Baseline"],"y":[0.0015332566236764312,0.0015474948163579129,0.0018505204835831495,0.0018350621233980864,0.001084194405687064,0.0016646791986888176,0.001906780690060376,0.001906780690060376,0.0016646791986888176,0.0016579609335016325,0.0019480907677665211,0.0],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="c72a7e53-f833-489f-bf04-17e867b40f55" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c72a7e53-f833-489f-bf04-17e867b40f55")) {                    Plotly.newPlot(                        "c72a7e53-f833-489f-bf04-17e867b40f55",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.1342495676261,0.1348644511419,0.1342049468925,0.1348157998322,0.1341220102531,0.1351870933696,0.1342838533008,0.1352628584334,0.1341251282824,0.1340023332124,0.1342797306632,0.1342191666867],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.1349003165960312,0.1344006210565567,0.13493786752223969,0.13478410243988037,0.13662678003311157,0.13508179783821106,0.13426493108272552,0.13426493108272552,0.13670533895492554,0.13764749467372894,0.13662678003311157,0.13463228940963745],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.1373247355222702,0.13654381036758423,0.1364828497171402,0.13615673780441284,0.13657265901565552,0.13627107441425323,0.13587532937526703,0.13629862666130066,0.135609433054924,0.1364828497171402,0.13523225486278534,0.13627107441425323],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.1373247355222702,0.13654381036758423,0.1364828497171402,0.13615673780441284,0.13657265901565552,0.13627107441425323,0.13587532937526703,0.13629862666130066,0.135609433054924,0.1364828497171402,0.13523225486278534,0.13627107441425323],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.13476529717445374,0.13459047675132751,0.13486498594284058,0.13460588455200195,0.13736632466316223,0.1350668966770172,0.1346847116947174,0.1346847116947174,0.13716381788253784,0.1372896432876587,0.1356467306613922,0.13480693101882935],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.137443408370018,0.13855068385601044,0.137443408370018,0.137443408370018,0.137443408370018,0.1367499828338623,0.137443408370018,0.137443408370018,0.137443408370018,0.137443408370018,0.137443408370018,0.137443408370018],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.1374717354774475,0.1352267861366272,0.13515469431877136,0.13491854071617126,0.13497045636177063,0.1374717354774475,0.1352892518043518,0.13515469431877136,0.13515469431877136,0.13515469431877136,0.13497045636177063,0.1374717354774475],"type":"scatter"},{"line":{"dash":"solid"},"marker ...
# Best model set SBFE breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
TLDPush_df = featureBusterMining(train_query,train_target,'TLD.Push',test_query, test_target,'MeAE','RF')
# Out:
# Target feature : TLD.Push_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="8a8b1a80-dee4-4287-94a7-dbb5277f6198" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a8b1a80-dee4-4287-94a7-dbb5277f6198")) {                    Plotly.newPlot(                        "8a8b1a80-dee4-4287-94a7-dbb5277f6198",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-172.5907673573,-142.260989238,-145.0943743343,-168.5486247087,-153.5723685337,-132.5241526172,-155.1583140064,-130.6091069115,-152.820015145,-161.8504525298,-146.4427347141,-168.6913134322,-142.8,-154.0087138386,-154.2580073754,-145.129277283,-155.1671158742,-152.3954959547,-165.8199577726,-156.2,-150.0551523859,-153.064648223,-153.7360376208,-130.910891282],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-172.5907673573,-142.260989238,-145.0943743343,-168.5486247087,-153.5723685337,-132.5241526172,-155.1583140064,-130.6091069115,-152.820015145,-161.8504525298,-146.4427347141,-168.6913134322,-142.8,-154.0087138386,-154.2580073754,-145.129277283,-155.1671158742,-152.3954959547,-165.8199577726,-156.2,-150.0551523859,-153.064648223,-153.7360376208,-130.910891282],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-172.5907673573,-142.260989238,-145.0943743343,-168.5486247087,-153.5723685337,-132.5241526172,-155.1583140064,-130.6091069115,-152.820015145,-161.8504525298,-146.4427347141,-168.6913134322,-142.8,-154.0087138386,-154.2580073754,-145.129277283,-155.1671158742,-152.3954959547,-165.8199577726,-156.2,-150.0551523859,-153.064648223,-153.7360376208,-130.910891282],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-172.5907673573,-142.260989238,-145.0943743343,-168.5486247087,-153.5723685337,-132.5241526172,-155.1583140064,-130.6091069115,-152.820015145,-161.8504525298,-146.4427347141,-168.6913134322,-142.8,-154.0087138386,-154.2580073754,-145.129277283,-155.1671158742,-152.3954959547,-165.8199577726,-156.2,-150.0551523859,-153.064648223,-153.7360376208,-130.910891282],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[-172.5907673573,-142.260989238,-145.0943743343,-168.5486247087,-153.5723685337,-132.5241526172,-155.1583140064,-130.6091069115,-152.820015145,-161.8504525 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="bb9e6734-3b8d-4e0c-bbc4-73ed7046538f" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb9e6734-3b8d-4e0c-bbc4-73ed7046538f")) {                    Plotly.newPlot(                        "bb9e6734-3b8d-4e0c-bbc4-73ed7046538f",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[-0.29710162060715595],"y":[0.6072877628476799],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.1264949581474667],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7793389028316196],"y":[0.3849501797543066],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.040599815861439494],"y":[-0.0655445717508701],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[0.1438929409481761],"y":[0.00019031406893090509],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.1808681867759575],"y":[-0.11547418355598908],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[0.03802582910675197],"y":[-0.15718639578141122],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.04627764412932415],"y":[-0.24040634755520762],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.0330756319707335],"y":[0.6899488625945127],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.32418774505666237],"y":[0.45458158751476874],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.13222724764858704],"y":[-0.24435166610503747],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.31264918195698416],"y":[0.2614900977687648],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.44621013391901154],"y":[0.23575278331407581],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.18894323242143704],"y":[-0.5155379482134357],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.0646042927112005],"y":[-0.6660515700988843],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.36949908562346323],"y":[0.0957558707813894],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"TLD.Push_target","x":[-0.4577376444621041],"y":[0.27459522441640666],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.29710162060715595,0.0330756319707335,null],"y":[0.6072877628476799,0.6899488625945127,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.29710162060715595,-0.4577376444621041,null],"y":[0.6072877628476799,0.27459522441640666,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.1264949581474667,0.0646042927112005,null],"y":[-1.0,-0.6660515700988843,null],"type":"scatt ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="e8fd5f9a-0323-41d5-84ee-269d6ca5d9af" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8fd5f9a-0323-41d5-84ee-269d6ca5d9af")) {                    Plotly.newPlot(                        "e8fd5f9a-0323-41d5-84ee-269d6ca5d9af",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","green","red","red","red","green","green","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","red","red","green","green","green","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","red","red","green","green","green","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","red","red","red","green","red","red","red","red","red","red","red","green","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","red","green","red","red","red","red","red","red","red","green","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","green","red","green","red","red","red","red","green","green","green","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="1218485c-2dd8-4578-82ca-89a19a7d7d73" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1218485c-2dd8-4578-82ca-89a19a7d7d73")) {                    Plotly.newPlot(                        "1218485c-2dd8-4578-82ca-89a19a7d7d73",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","green","green","green","green","green","green","green","green","green","orange"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["Laplacian","SBFE","Spearman","Kendall","Shuffle","Pearson","RFE","SFFE","ANOVA","PCA","MutualInfo","Baseline"],"xaxis":"x","y":[186.4351299958484,191.1850597408656,192.86008375022186,192.86008375022186,194.23819084438122,194.6744537907656,196.2885895329531,201.44635841584687,212.70413997236403,219.27442701403123,220.52954567374684,298.96688765600004],"yaxis":"y","type":"bar","text":["37.64%","36.05%","35.49%","35.49%","35.03%","34.88%","34.34%","32.62%","28.85%","26.66%","26.24%","0.0%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["Laplacian","SBFE","Spearman","Kendall","Shuffle","Pearson","RFE","SFFE","ANOVA","PCA","MutualInfo","Baseline"],"y":[6.246495520365197,5.247089711403835,5.433182246828802,5.433182246828802,4.9803703484914905,5.062202682909732,4.831735244817764,7.646171578853355,6.139541467944501,6.246495520365197,5.4437806443527945,0.0],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="96b3e69e-8dac-49e4-a682-bfd33b80adfb" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96b3e69e-8dac-49e4-a682-bfd33b80adfb")) {                    Plotly.newPlot(                        "96b3e69e-8dac-49e4-a682-bfd33b80adfb",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-137.0,-155.982160673,-147.0940974319,-145.5093741216,-152.9635448991,-149.68,-158.8818253307,-155.1556391129,-158.1741919196,0.0,-142.9756438121,-164.671464592],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-139.7725392503,-155.8761334072,-150.2266589958,-145.08,-155.7551480808,-149.5826896946,-146.4987697899,-145.0919218196,-164.2621096323,-159.9873728062,-243.6500962729,-165.1124207455],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-157.74546813964844,-152.05601501464844,-162.9665985107422,-156.5323944091797,-164.83834838867188,-158.17222595214844,-156.67396545410156,-161.68873596191406,-164.4644775390625,-158.92185974121094,-155.34352111816406,-150.4425506591797],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-158.4898223876953,-156.4452667236328,-161.79637145996094,-158.8708038330078,-153.87086486816406,-154.04759216308594,-153.9021759033203,-158.47447204589844,-153.9198760986328,-158.50245666503906,-149.75582885742188,-149.75582885742188],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-158.4898223876953,-156.4452667236328,-161.79637145996094,-158.8708038330078,-153.87086486816406,-154.04759216308594,-153.9021759033203,-158.47447204589844,-153.9198760986328,-158.50245666503906,-149.75582885742188,-149.75582885742188],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-165.4125213623047,-165.4125213623047,-165.4125213623047,-165.4125213623047,-165.4125213623047,-165.4125213623047,-165.4125213623047,-165.4125213623047,-165.4125213623047,-165.4125213623047,-165.4125213623047,-165.4125213623047],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-164.9365692138672,-164.35311889648438,-163.88514709472656,-167.0950164794922,-164.3677978515625,-164.36001586914062,-164.35311889648438,-163.5777130126953,-164.36001586914062,-163.50648498535156,-164.36001586914062,-164.36001586914062],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-143.82122802734375,-143.5269317626953,-143.82122802734375,-143.82122802734375,-143.5269317626953,-153.06341552734375,-143.82122802734375,-143.82122802734375,-143.82122802734375,-143.82122802734375,-143.82122802734375,-143.8212280273 ...
# Best model set Laplacian breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
AlignCorrAngleUHR_df = featureBusterMining(train_query,train_target,'AlignCorrAngleUHR',test_query, test_target,'MeAE','XGB+')
# Out:
# Target feature : AlignCorrAngleUHR_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="6c238098-d4d4-42eb-a76e-8c1dadc1b61c" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c238098-d4d4-42eb-a76e-8c1dadc1b61c")) {                    Plotly.newPlot(                        "6c238098-d4d4-42eb-a76e-8c1dadc1b61c",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-1.973395892176e-05,-5.993740555334e-05,4.919850787492e-05,-1.741051794908e-05,-0.0004909879620355,-3.280849587177e-05,-7.931394565013e-05,-4.132432722942e-05,3.836009085528e-05,0.0002131326130877,4.174667822612e-05,-0.0001026884591565,-0.0001226345676243,0.0001065,-4.528953618267e-05,-0.000215946696841,2.041621344893e-05,2.296840177593e-06,0.0001101259250149,-7.849979748064e-05,-7.00926363375e-06,-2.402187322541e-05,1.556127780165e-06,0.000364561220055],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-1.973395892176e-05,-5.993740555334e-05,4.919850787492e-05,-1.741051794908e-05,-0.0004909879620355,-3.280849587177e-05,-7.931394565013e-05,-4.132432722942e-05,3.836009085528e-05,0.0002131326130877,4.174667822612e-05,-0.0001026884591565,-0.0001226345676243,0.0001065,-4.528953618267e-05,-0.000215946696841,2.041621344893e-05,2.296840177593e-06,0.0001101259250149,-7.849979748064e-05,-7.00926363375e-06,-2.402187322541e-05,1.556127780165e-06,0.000364561220055],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-1.973395892176e-05,-5.993740555334e-05,4.919850787492e-05,-1.741051794908e-05,-0.0004909879620355,-3.280849587177e-05,-7.931394565013e-05,-4.132432722942e-05,3.836009085528e-05,0.0002131326130877,4.174667822612e-05,-0.0001026884591565,-0.0001226345676243,0.0001065,-4.528953618267e-05,-0.000215946696841,2.041621344893e-05,2.296840177593e-06,0.0001101259250149,-7.849979748064e-05,-7.00926363375e-06,-2.402187322541e-05,1.556127780165e-06,0.000364561220055],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-1.973395892176e-05,-5.993740555334e-05,4.919850787492e-05,-1.741051794908e-05,-0.0004909879620355,-3.280849587177e-05,-7.931394565013e-05,-4.132432722942e-05,3.836009085528e-05,0.0002131326130877,4.174667822612e-05,-0.0001026884591565,-0.0001226345676243,0.0001065,-4.528953618267e-05,-0.000215946696841,2.041621344893e-05,2.296840177593e-06,0.0001101259250149,-7.849979748064e-05,-7.00926363375e-06,-2.402187322541e-05,1.556127780165e-06,0.000364561220055],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="7a3f7567-3bf7-47e1-a207-f4cf5364775b" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a3f7567-3bf7-47e1-a207-f4cf5364775b")) {                    Plotly.newPlot(                        "7a3f7567-3bf7-47e1-a207-f4cf5364775b",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.2844161106754348],"y":[0.7679069101103209],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.22532676430267345],"y":[-0.49942565721263893],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.8214176353924507],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.1261254182122625],"y":[-0.11879202229237006],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[-0.030866096911027787],"y":[0.029607291182835026],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.05035580358437275],"y":[-0.1792179135243755],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.04861738068871023],"y":[-0.09284442096281055],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.11613161716859226],"y":[-0.05422813467711776],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.2215616096946638],"y":[0.598473635522999],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.1337692859019969],"y":[0.37232743312837857],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.036662047142670184],"y":[-0.0911829195599987],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[-0.0013470297173216535],"y":[0.2323947962540271],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.06870085765077788],"y":[0.23694514723222213],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.008679536112105136],"y":[-0.36686910403196127],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.12552459818470657],"y":[-0.33269418504015164],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.09263189462209945],"y":[0.1690863388356791],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"AlignCorrAngleUHR_target","x":[0.014947349611820466],"y":[0.3285128050349628],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.2844161106754348,0.2215616096946638,null],"y":[0.7679069101103209,0.598473635522999,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.22532676430267345,0.12552459818470657,null],"y":[-0.49942565721263893,-0.33269418504015164,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.1261254182122625,-0.030866096911027787,null],"y":[-0.11879202229237006,0.02 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="4088305d-d2f2-40f6-8d1d-55049c818f69" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4088305d-d2f2-40f6-8d1d-55049c818f69")) {                    Plotly.newPlot(                        "4088305d-d2f2-40f6-8d1d-55049c818f69",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","green","red","red","red","green","green","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","red","red","green","green","green","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","red","red","green","green","green","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","green","red","red","red","green","red","red","red","green","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","green","red","red","red","red","red","red","red","red","green","green","red","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","green","green","red","red","red","red","red","red","red","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="281907db-d685-48c2-a792-47734ac77858" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("281907db-d685-48c2-a792-47734ac77858")) {                    Plotly.newPlot(                        "281907db-d685-48c2-a792-47734ac77858",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","orange","red","red","red","red","red","red","red","red","red","red"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["PCA","Baseline","Pearson","Spearman","Kendall","MutualInfo","ANOVA","SFFE","SBFE","RFE","Shuffle","Laplacian"],"xaxis":"x","y":[0.00093302825198305,0.0013437391784494699,0.001383025130037753,0.001383025130037753,0.001383025130037753,0.001383025130037753,0.001383025130037753,0.001383025130037753,0.001383025130037753,0.001383025130037753,0.001383025130037753,0.001383025130037753],"yaxis":"y","type":"bar","text":["30.56%","0.0%","-2.92%","-2.92%","-2.92%","-2.92%","-2.92%","-2.92%","-2.92%","-2.92%","-2.92%","-2.92%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["PCA","Baseline","Pearson","Spearman","Kendall","MutualInfo","ANOVA","SFFE","SBFE","RFE","Shuffle","Laplacian"],"y":[6.960677820064356e-05,0.0,6.960677820064356e-05,6.960677820064356e-05,6.960677820064356e-05,6.960677820064356e-05,6.960677820064356e-05,6.960677820064356e-05,6.960677820064356e-05,6.960677820064356e-05,6.960677820064356e-05,6.960677820064356e-05],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","c ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="9c007d85-8f76-4151-bc0c-9087e921b024" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c007d85-8f76-4151-bc0c-9087e921b024")) {                    Plotly.newPlot(                        "9c007d85-8f76-4151-bc0c-9087e921b024",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-8.239706405728e-05,0.0,8.172953238964e-05,6.21153e-06,-0.000182544,-0.0002773244356354,0.0,-2.27579e-05,-0.000127464,-0.0002149368858518,-0.0002041898733056,-1.12944e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-3.43243964139e-05,-8.7790947262e-05,-3.925322375123e-05,-0.0002009381602112,-0.00016,-0.000179723741907,-0.0001084952906913,-0.000101675784366,0.0002919021501078,-0.0001455519799074,-0.0001556875647312,-4.622628377972e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05,-1.685443930909969e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22", ...
# Best model set PCA breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
CorrStigUppYUHR_df = featureBusterMining(train_query,train_target,'CorrStigUppYUHR',test_query, test_target,'MeAE','XGB')
# Out:
# Target feature : CorrStigUppYUHR_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="f0d29cb8-987d-44d6-9f53-57919e3d75a3" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0d29cb8-987d-44d6-9f53-57919e3d75a3")) {                    Plotly.newPlot(                        "f0d29cb8-987d-44d6-9f53-57919e3d75a3",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-0.05060756986335,-0.0264643935054,-0.006567836868572,0.003010810849357,0.01649914602024,0.02035328676539,0.004440626267976,-0.02078686500391,-0.006528300829464,-0.03081717424998,-0.04103371280942,-0.02211405159526,-0.008280867726146,-0.03608947636056,-0.0083056173801,0.03785134835394,-0.01395072609715,-0.001292423604367,-0.002006870953813,-0.02548689173929,0.02149479790245,-0.01967025186108,-0.04218488631356,-0.04684547371776],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-0.05060756986335,-0.0264643935054,-0.006567836868572,0.003010810849357,0.01649914602024,0.02035328676539,0.004440626267976,-0.02078686500391,-0.006528300829464,-0.03081717424998,-0.04103371280942,-0.02211405159526,-0.008280867726146,-0.03608947636056,-0.0083056173801,0.03785134835394,-0.01395072609715,-0.001292423604367,-0.002006870953813,-0.02548689173929,0.02149479790245,-0.01967025186108,-0.04218488631356,-0.04684547371776],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-0.05060756986335,-0.0264643935054,-0.006567836868572,0.003010810849357,0.01649914602024,0.02035328676539,0.004440626267976,-0.02078686500391,-0.006528300829464,-0.03081717424998,-0.04103371280942,-0.02211405159526,-0.008280867726146,-0.03608947636056,-0.0083056173801,0.03785134835394,-0.01395072609715,-0.001292423604367,-0.002006870953813,-0.02548689173929,0.02149479790245,-0.01967025186108,-0.04218488631356,-0.04684547371776],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-0.05060756986335,-0.0264643935054,-0.006567836868572,0.003010810849357,0.01649914602024,0.02035328676539,0.004440626267976,-0.02078686500391,-0.006528300829464,-0.03081717424998,-0.04103371280942,-0.02211405159526,-0.008280867726146,-0.03608947636056,-0.0083056173801,0.03785134835394,-0.01395072609715,-0.001292423604367,-0.002006870953813,-0.02548689173929,0.02149479790245,-0.01967025186108,-0.04218488631356,-0.04684547371776],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0. ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="09ebbaaf-53c2-44f1-9925-e186e1d6c7e3" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09ebbaaf-53c2-44f1-9925-e186e1d6c7e3")) {                    Plotly.newPlot(                        "09ebbaaf-53c2-44f1-9925-e186e1d6c7e3",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.45991493378488446],"y":[0.529294938510423],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.150118651648054],"y":[-0.4858577641367107],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-1.0],"y":[-0.006878463525767591],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.054493457969907],"y":[-0.08832331536929351],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[0.061922278881441924],"y":[0.006039564928175019],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.008600637935653173],"y":[-0.1554431486582096],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.03360354641827572],"y":[-0.03260005129492359],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[0.01399236093036173],"y":[-0.07914040568195377],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.38088804024716655],"y":[0.40032989971009897],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.27205851619643845],"y":[0.23257376505165975],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.08364185534278272],"y":[-0.11048319664274037],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.14640682421235623],"y":[0.15771610019890997],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.20059429870358417],"y":[0.13225730685644285],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.01415384771077227],"y":[-0.32010351193885367],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.10329435432503947],"y":[-0.32724064609399384],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.20744657139756842],"y":[0.062464197275886306],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"CorrStigUppYUHR_target","x":[-0.9694271956350693],"y":[0.08539473081085136],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.45991493378488446,0.38088804024716655,null],"y":[0.529294938510423,0.40032989971009897,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.150118651648054,0.10329435432503947,null],"y":[-0.4858577641367107,-0.32724064609399384,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-1.0,-0.9694271956350693,null],"y":[-0.006878463525767591,0.08539473081085136,nu ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="d894b069-f947-4bab-ad40-a469e1053d6f" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d894b069-f947-4bab-ad40-a469e1053d6f")) {                    Plotly.newPlot(                        "d894b069-f947-4bab-ad40-a469e1053d6f",                        [{"cells":{"align":"left","fill":{"color":[["red","green","green","red","red","green","green","red","green","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","green","green","red","red","red","red","red","red","red","red","red","red","green","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","red","red","red","red","red","red","red","red","red","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","green","red","red","red","green","green","green","red","green","red","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="3369373f-974f-4e31-a8bf-641820e8a220" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3369373f-974f-4e31-a8bf-641820e8a220")) {                    Plotly.newPlot(                        "3369373f-974f-4e31-a8bf-641820e8a220",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","orange","red","red","red","red","red","red","red","red","red","red"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["PCA","Baseline","ANOVA","Laplacian","Shuffle","MutualInfo","Pearson","Spearman","Kendall","SBFE","SFFE","RFE"],"xaxis":"x","y":[0.08664481902667154,0.1352860437025673,0.1784720261266573,0.2202066984095493,0.22406674175402613,0.23637770837052258,0.23870333364811974,0.2466744234597121,0.2466744234597121,0.24788399374391445,0.25634962448829757,0.29624614341163974],"yaxis":"y","type":"bar","text":["35.95%","0.0%","-31.92%","-62.77%","-65.62%","-74.72%","-76.44%","-82.34%","-82.34%","-83.23%","-89.49%","-118.98%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["PCA","Baseline","ANOVA","Laplacian","Shuffle","MutualInfo","Pearson","Spearman","Kendall","SBFE","SFFE","RFE"],"y":[0.012250349687579742,0.0,0.011256787536658243,0.012250349687579742,0.010648900562430537,0.013788866400881457,0.012551444895527184,0.01343181101997388,0.01343181101997388,0.011857711102044288,0.015078756427927623,0.011370989304646641],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinew ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="09d89c8e-3297-41ec-b1bd-e00a7a1a2959" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09d89c8e-3297-41ec-b1bd-e00a7a1a2959")) {                    Plotly.newPlot(                        "09d89c8e-3297-41ec-b1bd-e00a7a1a2959",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.002218776997876,0.0,-0.02447484911719,-0.00878352,0.0256801,0.01047328559624,0.0,-0.0195624,0.0017258,-0.0113252575983,0.00516997681683,0.00326347],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.001884820602032,0.01507067004955,-0.01038842863107,0.006913358211081,0.008451904143165,-0.002241685389111,0.01261983978725,-0.03015538345041,0.01533883651599,0.001357480125731,-0.0006926583259653,0.004277547893246],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.03251207619905472,-0.017456306144595146,-0.02971099317073822,-0.008735551498830318,0.029109222814440727,0.03520745038986206,-0.011312359943985939,-0.02579336054623127,0.008485197089612484,0.002753365784883499,0.03205692023038864,0.01368575356900692],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.019867906346917152,-0.013139232061803341,-0.035000089555978775,-0.00897926278412342,0.03316817060112953,0.03281640261411667,-0.010539913550019264,-0.036906272172927856,0.005947350524365902,-0.01465572975575924,0.02958812564611435,0.015114584006369114],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.019867906346917152,-0.013139232061803341,-0.035000089555978775,-0.00897926278412342,0.03316817060112953,0.03281640261411667,-0.010539913550019264,-0.036906272172927856,0.005947350524365902,-0.01465572975575924,0.02958812564611435,0.015114584006369114],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.017405668273568153,-0.02749449387192726,-0.038388241082429886,-0.013452952727675438,0.03004573844373226,0.021415794268250465,-0.005630250554531813,-0.030095014721155167,-0.017375269904732704,-0.011326282285153866,0.012621665373444557,0.008159514516592026],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.018601594492793083,-0.0067147077061235905,-0.010433000512421131,-0.01013429556041956,0.030537733808159828,0.025982171297073364,-0.004235059954226017,-0.010433000512421131,0.005510070826858282,0.0062360940501093864,0.01009147334843874,0.011007075197994709],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.028567414730787277,-0.025470327585935593,-0.04376992955803871,-0.01675759069621563,0.021478842943906784 ...
# Best model set PCA breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdACRotLow_df = featureBusterMining(train_query,train_target,'MdACRotLow',test_query, test_target,'MeAE','XGB')
# Out:
# Target feature : MdACRotLow_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="e148c200-64b7-4d5e-85cb-6ca1963d504f" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e148c200-64b7-4d5e-85cb-6ca1963d504f")) {                    Plotly.newPlot(                        "e148c200-64b7-4d5e-85cb-6ca1963d504f",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-0.00215,-0.001033549992537,-0.003041285093319,-0.00215,-0.003666397552903,-0.004814335353322,-0.0005489622367293,-0.0008367834042297,-0.000654681996885,-0.001000633827278,-0.001737167373214,-0.00215,-0.003357883026065,-0.0132442379489,-0.004540003824142,0.005833333333333,-0.000867263495457,-0.00215,0.0009951612903226,-0.00215,0.0050891969051,-0.00215,0.0006915836690733,0.009787842669845],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-0.00215,-0.001033549992537,-0.003041285093319,-0.00215,-0.003666397552903,-0.004814335353322,-0.0005489622367293,-0.0008367834042297,-0.000654681996885,-0.001000633827278,-0.001737167373214,-0.00215,-0.003357883026065,-0.0132442379489,-0.004540003824142,0.005833333333333,-0.000867263495457,-0.00215,0.0009951612903226,-0.00215,0.0050891969051,-0.00215,0.0006915836690733,0.009787842669845],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-0.00215,-0.001033549992537,-0.003041285093319,-0.00215,-0.003666397552903,-0.004814335353322,-0.0005489622367293,-0.0008367834042297,-0.000654681996885,-0.001000633827278,-0.001737167373214,-0.00215,-0.003357883026065,-0.0132442379489,-0.004540003824142,0.005833333333333,-0.000867263495457,-0.00215,0.0009951612903226,-0.00215,0.0050891969051,-0.00215,0.0006915836690733,0.009787842669845],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-0.00215,-0.001033549992537,-0.003041285093319,-0.00215,-0.003666397552903,-0.004814335353322,-0.0005489622367293,-0.0008367834042297,-0.000654681996885,-0.001000633827278,-0.001737167373214,-0.00215,-0.003357883026065,-0.0132442379489,-0.004540003824142,0.005833333333333,-0.000867263495457,-0.00215,0.0009951612903226,-0.00215,0.0050891969051,-0.00215,0.0006915836690733,0.009787842669845],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[-0.00215,-0.001033549992537,-0.003 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="083093ca-8531-4606-abca-ea9c73ec1887" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("083093ca-8531-4606-abca-ea9c73ec1887")) {                    Plotly.newPlot(                        "083093ca-8531-4606-abca-ea9c73ec1887",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.08571319442723281],"y":[0.677332166486647],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.1845775840388866],"y":[-0.510405404819265],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7764289506410436],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.11805070706269763],"y":[-0.018407530822865264],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[0.007796325840370421],"y":[0.05529038168648394],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.03432968861625269],"y":[-0.0022824145758067204],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.03906897820721272],"y":[-0.09619751834755305],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.10671650198285731],"y":[-0.08832246259537112],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.07654459222937919],"y":[0.48212140994578684],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.1670931376903294],"y":[0.3259366135000396],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.05427085014723383],"y":[-0.08193678796177277],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.07238332659597423],"y":[0.2150683207320872],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.13323922692276285],"y":[0.21433467781452697],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[0.004091046996001085],"y":[-0.24125025963892974],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.11584052315238315],"y":[-0.3261144666042154],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.17389555845413873],"y":[0.12638565982160782],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdACRotLow_target","x":[-0.000850539984628434],"y":[0.2684476153785993],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.08571319442723281,0.07654459222937919,null],"y":[0.677332166486647,0.48212140994578684,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.1845775840388866,0.11584052315238315,null],"y":[-0.510405404819265,-0.3261144666042154,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.11805070706269763,0.007796325840370421,null],"y":[-0.018407530822865264,0.0552903816 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="a59f5795-8566-40de-9c94-65721eb0edfd" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a59f5795-8566-40de-9c94-65721eb0edfd")) {                    Plotly.newPlot(                        "a59f5795-8566-40de-9c94-65721eb0edfd",                        [{"cells":{"align":"left","fill":{"color":[["red","green","green","red","red","green","green","red","green","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","green","red","red","red","red","red","red","green","green","red","red","red","red","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","green","red","red","green","red","red","green","green","red","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","red","green","green","red","green","green","green","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="d4926329-389f-49da-b680-821261124635" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4926329-389f-49da-b680-821261124635")) {                    Plotly.newPlot(                        "d4926329-389f-49da-b680-821261124635",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","orange","red","red","red","red","red","red","red","red","red","red"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["ANOVA","Baseline","Laplacian","RFE","Spearman","Kendall","SBFE","SFFE","Shuffle","Pearson","MutualInfo","PCA"],"xaxis":"x","y":[0.037892422607214,0.04040873259899528,0.05285214330233532,0.05356466696147021,0.054137612432973985,0.054137612432973985,0.05421795186892763,0.054916286494732534,0.0553794557318592,0.05554698678505287,0.06480586660932415,0.08207355335565969],"yaxis":"y","type":"bar","text":["6.23%","0.0%","-30.79%","-32.56%","-33.98%","-33.98%","-34.17%","-35.9%","-37.05%","-37.46%","-60.38%","-103.11%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["ANOVA","Baseline","Laplacian","RFE","Spearman","Kendall","SBFE","SFFE","Shuffle","Pearson","MutualInfo","PCA"],"y":[0.001943781454913529,0.0,0.0020705364901433937,0.0015297424777493847,0.0017947652235239045,0.0017947652235239045,0.0014728731563786208,0.0019068231234260124,0.0018978347236937906,0.0019057705616933017,0.00161218064571215,0.0020705364901433937],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorba ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="a648ab05-bc40-459c-b272-e81e3f18d3d2" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a648ab05-bc40-459c-b272-e81e3f18d3d2")) {                    Plotly.newPlot(                        "a648ab05-bc40-459c-b272-e81e3f18d3d2",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.003210732054201,0.001754510780768,-0.00215,-0.0106628537536,0.001816777400703,-0.00215,0.002198240678936,0.002462106884637,0.0007610630839135,0.002969254839655,0.005941897943687,3.129517889478e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.005110516678541899,-0.0002769341808743775,0.0014549462357535958,0.0017878002254292369,0.0047853849828243256,0.00448398943990469,0.004636160098016262,0.0013581878738477826,-0.0013378943549469113,0.001098453183658421,0.0005072738276794553,0.00662116939201951],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.005304249003529549,-0.0008206691709347069,0.001554864807985723,0.0015623405342921615,0.004435993265360594,0.005151322577148676,0.004624726716428995,0.0014854304026812315,-0.0006330826436169446,0.001671331119723618,0.001110886805690825,0.006301905959844589],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.005304249003529549,-0.0008206691709347069,0.001554864807985723,0.0015623405342921615,0.004435993265360594,0.005151322577148676,0.004624726716428995,0.0014854304026812315,-0.0006330826436169446,0.001671331119723618,0.001110886805690825,0.006301905959844589],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.00508099002763629,-0.0010509620187804103,0.004772847983986139,0.004772847983986139,0.005178514402359724,0.00496674794703722,0.004772847983986139,0.004772847983986139,-0.0009543978958390653,0.005178514402359724,-0.0013016059529036283,0.004849359393119812],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.004255341365933418,0.0013340688310563564,0.0010630134493112564,0.0010630134493112564,0.0013340688310563564,0.0010630134493112564,0.0010630134493112564,0.004255341365933418,0.0013870617840439081,0.0010630134493112564,0.0010630134493112564,0.0010630134493112564],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.0023243892937898636,-0.0022790879011154175,0.0014660251326858997,0.0006295160274021327,-0.00037141735083423555,-0.0023243892937898636,-0.00232438929378986 ...
# Best model set ANOVA breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdCompUHRRem_df = featureBusterMining(train_query,train_target,'MdCompUHRRem',test_query, test_target,'MeAE','XGB')
# Out:
# Target feature : MdCompUHRRem_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="d731686e-4b98-42c7-bf24-3905b099cbdb" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d731686e-4b98-42c7-bf24-3905b099cbdb")) {                    Plotly.newPlot(                        "d731686e-4b98-42c7-bf24-3905b099cbdb",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-4.96,-5.0,-5.0,-5.0,-5.0,-5.0,-19.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.02,-4.94,-5.0,-5.0,-20.0,-5.0,-5.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-4.96,-5.0,-5.0,-5.0,-5.0,-5.0,-19.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.02,-4.94,-5.0,-5.0,-20.0,-5.0,-5.0],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-4.96,-5.0,-5.0,-5.0,-5.0,-5.0,-19.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.02,-4.94,-5.0,-5.0,-20.0,-5.0,-5.0],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-4.96,-5.0,-5.0,-5.0,-5.0,-5.0,-19.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.02,-4.94,-5.0,-5.0,-20.0,-5.0,-5.0],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[-4.96,-5.0,-5.0,-5.0,-5.0,-5.0,-19.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.02,-4.94,-5.0,-5.0,-20.0,-5.0,-5.0],"type":"scatter","xaxis":"x5","yaxis":"y5"},{"mode":"markers","showlegend":false,"x":[-20.0,-20.0,-10.0,-20.0,-20.0,-20.0,-20.0,-20.0,-10.0,-20.0,-10.0,-20.0,-20.0,-20.0,-20.0,-10.0,-20.0,-20.0,-20.0,-20.0,-10.0,-10.0,-20.0,-10.0],"y":[-4.96,-5.0,-5.0,-5.0,-5.0,-5.0,-19.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.02,-4.94,-5.0,-5.0,-20.0,-5.0,-5.0],"type":"scatter","xaxis":"x6","yaxis":"y6"},{"mode":"markers","showlegend":false,"x":[0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.145855,0.1356308563075,0.145855,0.145855],"y":[-4.96,-5.0,-5.0,-5.0,-5.0,-5.0,-19.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.0,-5.02,-4.94,-5.0,-5.0,-20.0,-5.0,-5.0],"type":"scatter","xaxis":"x7","yaxis":"y7"},{"mode":"markers","showlegend":false,"x":[0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="6f364019-ee27-404f-aee8-4a09486806ad" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f364019-ee27-404f-aee8-4a09486806ad")) {                    Plotly.newPlot(                        "6f364019-ee27-404f-aee8-4a09486806ad",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.4196571974027683],"y":[0.6831420752915137],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.14057519246448083],"y":[-0.4691121178415855],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7662072143665623],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.16511856005223718],"y":[-0.022458652479157598],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[-0.03196036760865742],"y":[0.0723986096717187],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.08038169655673265],"y":[-0.12649933610388955],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.08611803817634875],"y":[-0.004441051076539043],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.12031806263897558],"y":[-0.05915846498418968],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.32678809834393874],"y":[0.5385091715913377],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.20194379584973915],"y":[0.34834036696412557],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[-0.0031984097037495085],"y":[-0.04866728307216651],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.05946802162023402],"y":[0.2574099036137897],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.12062399244359108],"y":[0.23124684706012735],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.06613924985501096],"y":[-0.31553125558310674],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.06308830895550012],"y":[-0.2949859092852647],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.13420534599268544],"y":[0.15385392541113463],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdCompUHRRem_target","x":[-0.1469083541146634],"y":[0.05595317082215198],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.4196571974027683,0.32678809834393874,null],"y":[0.6831420752915137,0.5385091715913377,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.14057519246448083,0.06308830895550012,null],"y":[-0.4691121178415855,-0.2949859092852647,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.16511856005223718,-0.03196036760865742,null],"y":[-0.022458652479157598,0.0723 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="2c018a87-c51a-4e59-a715-7bd761ada945" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c018a87-c51a-4e59-a715-7bd761ada945")) {                    Plotly.newPlot(                        "2c018a87-c51a-4e59-a715-7bd761ada945",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","red","red","red","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","green","red","red","green","red","red","red","red","red","red","red","green","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","green","green","red","green","green","red","red","red","red","red","red","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","green","green","red","green","green","red","red","red","green","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="2dfe1179-57bb-4ad9-83fb-7e8edab735ae" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dfe1179-57bb-4ad9-83fb-7e8edab735ae")) {                    Plotly.newPlot(                        "2dfe1179-57bb-4ad9-83fb-7e8edab735ae",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","green","green","green","green","green","green","green","green","green","orange"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["SBFE","PCA","ANOVA","SFFE","Pearson","Spearman","Kendall","Shuffle","RFE","Laplacian","MutualInfo","Baseline"],"xaxis":"x","y":[18.82636982190254,33.08495670544746,35.71218925702217,93.63606968157646,117.2012495399749,117.2012495399749,117.2012495399749,117.2012495399749,117.20177787554618,117.20177787554618,117.21842759859916,127.2091316582],"yaxis":"y","type":"bar","text":["85.2%","73.99%","71.93%","26.39%","7.87%","7.87%","7.87%","7.87%","7.87%","7.87%","7.85%","0.0%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["SBFE","PCA","ANOVA","SFFE","Pearson","Spearman","Kendall","Shuffle","RFE","Laplacian","MutualInfo","Baseline"],"y":[0.004717276891072597,1.049041748046875e-05,0.2429021199544271,0.3434433937072754,0.001806186040242519,0.001806186040242519,0.001806186040242519,0.001806186040242519,8.344650268554688e-05,1.049041748046875e-05,0.010077956517537364,0.0],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="51dabf9f-1324-4c3b-8aff-2119f96709d3" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51dabf9f-1324-4c3b-8aff-2119f96709d3")) {                    Plotly.newPlot(                        "51dabf9f-1324-4c3b-8aff-2119f96709d3",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-20.0,-20.0,-20.0,-20.0,-20.0,-20.0,-20.0,-20.0,-20.0,-10.0,-10.0,-20.0],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-5.0,-5.0,-5.0,-17.9024,-5.0,-5.0,-5.0,-20.0,-5.0,-9.8884683418,-5.0,-5.0],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-19.998966217041016,-4.999805927276611,-19.998966217041016,-19.998966217041016,-4.999805927276611,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-19.998966217041016,-4.999805927276611,-19.998966217041016,-19.998966217041016,-4.999805927276611,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-19.998966217041016,-4.999805927276611,-19.998966217041016,-19.998966217041016,-4.999805927276611,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016,-19.998966217041016],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-19.998626708984375,-5.019111633300781,-19.998626708984375,-19.999038696289062,-5.000346660614014,-19.998626708984375,-19.998626708984375,-19.999038696289062,-19.999038696289062,-19.998626708984375,-19.998626708984375,-19.999038696289062],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-5.233691692352295,-4.006722927093506,-5.233691692352295,-5.233691692352295,-4.006722927093506,-5.233691692352295,-5.233691692352295,-5.233691692352295,-5.233691692352295,-5.233691692352295,-5.233691692352295,-5.233691692352295],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-16.45315933227539,-4.0484089851379395,-16.45315933227539,-16.45315933227539,-4.0484089851379395,-16.45315933227539,-16.45315933227539,-16.45315933227539,-16.45315933227539,-16.45315933227539,-16.45315933227539,-16.45315933227539],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"pink","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sbfe","x":["8","10","12","13","16","17","19","22","25","3 ...
# Best model set SBFE breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdDeflDC1_df = featureBusterMining(train_query,train_target,'MdDeflDC1',test_query, test_target,'MeAE','XGB+')
# Out:
# Target feature : MdDeflDC1_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="b1226fee-6435-4248-9bad-ba4365d9bfc3" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1226fee-6435-4248-9bad-ba4365d9bfc3")) {                    Plotly.newPlot(                        "b1226fee-6435-4248-9bad-ba4365d9bfc3",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[0.1576327608488,0.1458026577705,0.1456359119666,0.1488882223217,0.1466344315424,0.1459359362986,0.1577796093592,0.1573466767617,0.1578844133413,0.148980852038,0.1457217227922,0.142192334377,0.1582453320955,0.1489189566828,0.1458994401116,0.1420677043358,0.1421231064659,0.1425105775446,0.142703972503,0.1418153378943,0.146283786978,0.1457481135945,0.146464500193,0.142773258349],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[0.1576327608488,0.1458026577705,0.1456359119666,0.1488882223217,0.1466344315424,0.1459359362986,0.1577796093592,0.1573466767617,0.1578844133413,0.148980852038,0.1457217227922,0.142192334377,0.1582453320955,0.1489189566828,0.1458994401116,0.1420677043358,0.1421231064659,0.1425105775446,0.142703972503,0.1418153378943,0.146283786978,0.1457481135945,0.146464500193,0.142773258349],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[0.1576327608488,0.1458026577705,0.1456359119666,0.1488882223217,0.1466344315424,0.1459359362986,0.1577796093592,0.1573466767617,0.1578844133413,0.148980852038,0.1457217227922,0.142192334377,0.1582453320955,0.1489189566828,0.1458994401116,0.1420677043358,0.1421231064659,0.1425105775446,0.142703972503,0.1418153378943,0.146283786978,0.1457481135945,0.146464500193,0.142773258349],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[0.1576327608488,0.1458026577705,0.1456359119666,0.1488882223217,0.1466344315424,0.1459359362986,0.1577796093592,0.1573466767617,0.1578844133413,0.148980852038,0.1457217227922,0.142192334377,0.1582453320955,0.1489189566828,0.1458994401116,0.1420677043358,0.1421231064659,0.1425105775446,0.142703972503,0.1418153378943,0.146283786978,0.1457481135945,0.146464500193,0.142773258349],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[0.1576327608488,0.1458026577705,0.1456359119666,0.1488882223217,0.1466344315424,0.1459 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="39f7afea-8d03-480c-83e8-2ee37a7a5fc7" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39f7afea-8d03-480c-83e8-2ee37a7a5fc7")) {                    Plotly.newPlot(                        "39f7afea-8d03-480c-83e8-2ee37a7a5fc7",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.49829253660860556],"y":[0.5482915641849034],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.09707144337376497],"y":[-0.5208531261155896],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7349546176915233],"y":[-0.9568606177007711],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.08942684400044155],"y":[-0.020940063822796503],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[0.017391423718227775],"y":[0.014692979882291957],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.06718252013727517],"y":[-0.1559043011901485],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.11656338561932585],"y":[-0.08041122045183315],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.04176642695056149],"y":[-0.07514839033273589],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.39884842326116376],"y":[0.41578374673204493],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.26242685069804433],"y":[0.24431154265816765],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.03447263510064944],"y":[-0.11310188183110949],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.11755816861099735],"y":[0.1735811671079455],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.17434144959381434],"y":[0.1431235998916409],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.0796796913933124],"y":[-0.3344820438641928],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.050178402825582356],"y":[-0.34838104948823445],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.18128736707901708],"y":[0.06629809434041772],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdDeflDC1_target","x":[-0.702295215077427],"y":[1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.49829253660860556,0.39884842326116376,null],"y":[0.5482915641849034,0.41578374673204493,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.09707144337376497,0.050178402825582356,null],"y":[-0.5208531261155896,-0.34838104948823445,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.08942684400044155,0.017391423718227775,null],"y":[-0.020940063822796503,0.0146929 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="d3a9453a-9670-4674-8d9c-b240496b7539" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3a9453a-9670-4674-8d9c-b240496b7539")) {                    Plotly.newPlot(                        "d3a9453a-9670-4674-8d9c-b240496b7539",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","green","green","red","red","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","green","red","red","green","red","red","red","red","red","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","red","red","red","green","green","green","red","red","red","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","green","red","red","green","green","green","red","red","green","red","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="2e0764f2-8bf7-47a9-b461-909c8375da03" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e0764f2-8bf7-47a9-b461-909c8375da03")) {                    Plotly.newPlot(                        "2e0764f2-8bf7-47a9-b461-909c8375da03",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","green","green","green","green","green","green","green","green","green","orange"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["PCA","ANOVA","Laplacian","SFFE","MutualInfo","Pearson","Spearman","Kendall","SBFE","Shuffle","RFE","Baseline"],"xaxis":"x","y":[0.04822234437219999,0.05691197418572999,0.06400531334985085,0.0711680787781204,0.07308565779471668,0.07856969026591612,0.07951938597228361,0.07951938597228361,0.0796885319569672,0.08135925419454235,0.08694946547537694,0.08735899823659996],"yaxis":"y","type":"bar","text":["44.8%","34.85%","26.73%","18.53%","16.34%","10.06%","8.97%","8.97%","8.78%","6.87%","0.47%","0.0%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["PCA","ANOVA","Laplacian","SFFE","MutualInfo","Pearson","Spearman","Kendall","SBFE","Shuffle","RFE","Baseline"],"y":[0.004569754138834194,0.004852276173315628,0.004569754138834194,0.004160711292617793,0.00457198737409828,0.00576295270444481,0.005348248376229843,0.005348248376229843,0.004393834420026545,0.005029857259034339,0.004601864265133783,0.0],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"ou ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="2bdad4a4-56ec-42e5-85cf-93eb72b83d22" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bdad4a4-56ec-42e5-85cf-93eb72b83d22")) {                    Plotly.newPlot(                        "2bdad4a4-56ec-42e5-85cf-93eb72b83d22",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.1574774447788,0.1459888287677,0.1457728732996,0.1460612736621,0.1454826782174,0.1575857753365,0.1460627645667,0.1462256269937,0.1457999084187,0.1583350506524,0.1460806443906,0.1576861291524],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.14421911537647247,0.15129445493221283,0.15476791560649872,0.14779677987098694,0.14525902271270752,0.14459764957427979,0.1502866894006729,0.1560995727777481,0.14756126701831818,0.14984005689620972,0.14750684797763824,0.14740315079689026],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.14400358498096466,0.15034449100494385,0.15694750845432281,0.14705762267112732,0.14504654705524445,0.1436053067445755,0.1495267152786255,0.15715567767620087,0.1475256085395813,0.15104542672634125,0.14737553894519806,0.14728806912899017],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.14400358498096466,0.15034449100494385,0.15694750845432281,0.14705762267112732,0.14504654705524445,0.1436053067445755,0.1495267152786255,0.15715567767620087,0.1475256085395813,0.15104542672634125,0.14737553894519806,0.14728806912899017],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.14234717190265656,0.14443030953407288,0.1458306610584259,0.14374899864196777,0.14547543227672577,0.1417139768600464,0.14296667277812958,0.14640159904956818,0.15094998478889465,0.1458306610584259,0.1447693109512329,0.14177623391151428],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.14512750506401062,0.14573603868484497,0.14695610105991364,0.1458607167005539,0.14599986374378204,0.1492086797952652,0.14484690129756927,0.15035061538219452,0.14834405481815338,0.14733237028121948,0.14519107341766357,0.14343219995498657],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.14325056970119476,0.14556248486042023,0.1560705453157425,0.14233331382274628,0.14262141287326813,0.14744940400123596,0.14556248486042023,0.14649510383605957,0.14556248486042023,0.14242109656333923,0.1455981582403183,0.1455981582403183],"type":"scatter"},{"line":{"dash":"solid"},"mark ...
# Best model set PCA breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdHRSatPar1_df = featureBusterMining(train_query,train_target,'MdHRSatPar1',test_query, test_target,'MeAE','XGB')
# Out:
# Target feature : MdHRSatPar1_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="28e782ae-f499-4338-983d-da19190ec024" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28e782ae-f499-4338-983d-da19190ec024")) {                    Plotly.newPlot(                        "28e782ae-f499-4338-983d-da19190ec024",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-14.14868026605,-24.41970330864,-21.34881482011,-19.07737958798,-20.15015040077,-20.88846987525,-21.48438533908,-21.29128241403,-23.49106225231,-21.07306379266,-18.60387563077,-21.61134005994,-25.33180087065,-23.49858897519,-20.55961584532,-15.17906934615,-17.57200300383,-22.06204523708,-22.39098440729,-23.1034865516,-24.31094423106,-21.76139807774,-21.48695857464,-23.26374406634],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-14.14868026605,-24.41970330864,-21.34881482011,-19.07737958798,-20.15015040077,-20.88846987525,-21.48438533908,-21.29128241403,-23.49106225231,-21.07306379266,-18.60387563077,-21.61134005994,-25.33180087065,-23.49858897519,-20.55961584532,-15.17906934615,-17.57200300383,-22.06204523708,-22.39098440729,-23.1034865516,-24.31094423106,-21.76139807774,-21.48695857464,-23.26374406634],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-14.14868026605,-24.41970330864,-21.34881482011,-19.07737958798,-20.15015040077,-20.88846987525,-21.48438533908,-21.29128241403,-23.49106225231,-21.07306379266,-18.60387563077,-21.61134005994,-25.33180087065,-23.49858897519,-20.55961584532,-15.17906934615,-17.57200300383,-22.06204523708,-22.39098440729,-23.1034865516,-24.31094423106,-21.76139807774,-21.48695857464,-23.26374406634],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-14.14868026605,-24.41970330864,-21.34881482011,-19.07737958798,-20.15015040077,-20.88846987525,-21.48438533908,-21.29128241403,-23.49106225231,-21.07306379266,-18.60387563077,-21.61134005994,-25.33180087065,-23.49858897519,-20.55961584532,-15.17906934615,-17.57200300383,-22.06204523708,-22.39098440729,-23.1034865516,-24.31094423106,-21.76139807774,-21.48695857464,-23.26374406634],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[-14.14868026605,-24.41970330864,-21.34881482011,-19.07737958798,-2 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="ee166b4c-ec8b-4336-a924-cf917ea6c91e" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee166b4c-ec8b-4336-a924-cf917ea6c91e")) {                    Plotly.newPlot(                        "ee166b4c-ec8b-4336-a924-cf917ea6c91e",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.21840413259735075],"y":[0.6902363490373883],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.1975918192223568],"y":[-0.5125917673487866],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7675833965021129],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.1327211565125626],"y":[-0.05423589931498288],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[-0.03601058501080916],"y":[0.0215143385470225],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.06170237641732313],"y":[-0.17958368176486714],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.1285923188622345],"y":[-0.12002113877737781],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.05914339690645594],"y":[-0.0844165582246685],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.14076983566558907],"y":[0.5707585332413627],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.12123614568312027],"y":[0.36345159359232626],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.026688365633821275],"y":[-0.10149890421665134],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.003925175582878291],"y":[0.2213567645648388],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.07216174363263032],"y":[0.21255718973519797],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.0265873457479785],"y":[-0.3663867778128523],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.10746954798003994],"y":[-0.34373096697816913],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.10386055733524556],"y":[0.1384864707254247],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdHRSatPar1_target","x":[0.22023325262644422],"y":[0.5441044549947939],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.21840413259735075,0.14076983566558907,null],"y":[0.6902363490373883,0.5707585332413627,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.21840413259735075,0.22023325262644422,null],"y":[0.6902363490373883,0.5441044549947939,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.1975918192223568,0.10746954798003994,null],"y":[-0.5125917673487866,-0.34373096697816913,n ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="b260f0cb-769a-44bd-96bb-69ecd7f37141" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b260f0cb-769a-44bd-96bb-69ecd7f37141")) {                    Plotly.newPlot(                        "b260f0cb-769a-44bd-96bb-69ecd7f37141",                        [{"cells":{"align":"left","fill":{"color":[["red","green","green","red","red","green","green","red","green","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","red","red","red","green","red","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","red","red","red","red","red","red","green","green","green","red","red","red","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","green","green","green","red","red","green","green","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="645e4c83-9a94-42f0-98fc-54db5cb79b34" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("645e4c83-9a94-42f0-98fc-54db5cb79b34")) {                    Plotly.newPlot(                        "645e4c83-9a94-42f0-98fc-54db5cb79b34",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","green","green","green","green","green","orange","red","red","red","red"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["RFE","PCA","SFFE","Shuffle","MutualInfo","Spearman","Kendall","Baseline","SBFE","ANOVA","Pearson","Laplacian"],"xaxis":"x","y":[27.13207456847994,28.81143433467231,29.107784726886447,30.28102718318922,31.171160998708356,31.21474872554762,31.21474872554762,31.838735128420005,32.434814665525835,32.941668066603754,34.65975782653658,40.75939964808183],"yaxis":"y","type":"bar","text":["14.78%","9.51%","8.58%","4.89%","2.1%","1.96%","1.96%","0.0%","-1.87%","-3.46%","-8.86%","-28.02%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["RFE","PCA","SFFE","Shuffle","MutualInfo","Spearman","Kendall","Baseline","SBFE","ANOVA","Pearson","Laplacian"],"y":[1.1925644787435221,1.6301146387474674,1.882645107316172,1.197001417441621,1.2422251142691014,1.157384835902181,1.157384835902181,0.0,1.2142622701199344,1.1884612976080084,0.8568190283672076,1.6301146387474674],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="8bb5f8de-e149-4a39-82f5-faf0a38ea55e" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bb5f8de-e149-4a39-82f5-faf0a38ea55e")) {                    Plotly.newPlot(                        "8bb5f8de-e149-4a39-82f5-faf0a38ea55e",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-19.89886373553,-22.89373009742,-21.15294814621,-21.4805635044,-21.9362844366,-21.9808333459,-20.66296785733,-19.28292088077,-17.72363047494,-26.11590892779,-26.03176359044,-20.70204495845],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-20.61129256835,-21.84357353213,-13.55446842334,-21.22966126017,-19.25295625247,-30.16432836182,-21.88782686346,-22.47047455311,-20.07417259169,-22.69214112135,-24.98920119276,-20.57138539463],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-22.86554718017578,-23.9277286529541,-18.194007873535156,-21.904218673706055,-15.693816184997559,-23.500680923461914,-23.59263801574707,-18.103591918945312,-23.49134063720703,-22.796083450317383,-23.222187042236328,-23.996030807495117],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-22.59315299987793,-22.52050018310547,-16.64183235168457,-22.222139358520508,-16.219833374023438,-22.307279586791992,-23.273778915405273,-17.37086296081543,-22.13764762878418,-22.365678787231445,-23.064708709716797,-23.35733985900879],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-22.59315299987793,-22.52050018310547,-16.64183235168457,-22.222139358520508,-16.219833374023438,-22.307279586791992,-23.273778915405273,-17.37086296081543,-22.13764762878418,-22.365678787231445,-23.064708709716797,-23.35733985900879],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-21.64768409729004,-22.81586265563965,-22.784730911254883,-20.66459846496582,-21.126192092895508,-21.646528244018555,-21.502277374267578,-22.784730911254883,-23.318588256835938,-22.784730911254883,-21.126192092895508,-21.64768409729004],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-19.474435806274414,-22.6363525390625,-19.882144927978516,-20.746368408203125,-20.746368408203125,-20.49845314025879,-19.474435806274414,-19.474435806274414,-22.43010139465332,-22.159404754638672,-22.124116897583008,-22.449981689453125],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-20.54181671142578,-21.635751724243164,-20.54181671142578,-20.54181671142578,-21.635751724243164,-21.76141929626465,-20.54181671142578,-20.54181671142578,-20.54181671142578,-20.54181671142578, ...
# Best model set RFE breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
ShiftCorrAngleUHR_df = featureBusterMining(train_query,train_target,'ShiftCorrAngleUHR',test_query, test_target,'MeAE','XGB+')
# Out:
# Target feature : ShiftCorrAngleUHR_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="d92f7b95-b8c6-479e-a81b-1d336d06e49a" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d92f7b95-b8c6-479e-a81b-1d336d06e49a")) {                    Plotly.newPlot(                        "d92f7b95-b8c6-479e-a81b-1d336d06e49a",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-0.0001174312571815,0.0002040171363528,-0.0006875257795614,-8.333333333333e-06,0.0002302904359626,-0.0001538847409481,-0.0009502443777878,0.0001362661516127,0.0006902759841337,5.065348705198e-05,9.702175033949e-05,0.00025,-0.0002216246885599,-0.0001130467634291,-0.0002030620414953,-0.0002254600596781,0.0001472023645054,0.0005197466981209,-0.0007166666666667,0.0007916666666667,-5.749696070153e-05,-0.0004083333333333,-0.0006835221367577,-0.0007148640874878],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-0.0001174312571815,0.0002040171363528,-0.0006875257795614,-8.333333333333e-06,0.0002302904359626,-0.0001538847409481,-0.0009502443777878,0.0001362661516127,0.0006902759841337,5.065348705198e-05,9.702175033949e-05,0.00025,-0.0002216246885599,-0.0001130467634291,-0.0002030620414953,-0.0002254600596781,0.0001472023645054,0.0005197466981209,-0.0007166666666667,0.0007916666666667,-5.749696070153e-05,-0.0004083333333333,-0.0006835221367577,-0.0007148640874878],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-0.0001174312571815,0.0002040171363528,-0.0006875257795614,-8.333333333333e-06,0.0002302904359626,-0.0001538847409481,-0.0009502443777878,0.0001362661516127,0.0006902759841337,5.065348705198e-05,9.702175033949e-05,0.00025,-0.0002216246885599,-0.0001130467634291,-0.0002030620414953,-0.0002254600596781,0.0001472023645054,0.0005197466981209,-0.0007166666666667,0.0007916666666667,-5.749696070153e-05,-0.0004083333333333,-0.0006835221367577,-0.0007148640874878],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-0.0001174312571815,0.0002040171363528,-0.0006875257795614,-8.333333333333e-06,0.0002302904359626,-0.0001538847409481,-0.0009502443777878,0.0001362661516127,0.0006902759841337,5.065348705198e-05,9.702175033949e-05,0.00025,-0.0002216246885599,-0.0001130467634291,-0.0002030620414953,-0.0002254600596781,0.0001472023645054,0.0005197466981209,-0.0007166666666667,0.0007916666666667,-5.749696070153e-05,-0.0004083333333333,-0.0006835221367577,-0.0007148640874878],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mo ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="f8d5b248-cf1f-40c1-9517-c4bcdabf956d" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8d5b248-cf1f-40c1-9517-c4bcdabf956d")) {                    Plotly.newPlot(                        "f8d5b248-cf1f-40c1-9517-c4bcdabf956d",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.333320812860949],"y":[0.7693241770073942],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.17971855629801142],"y":[-0.5290525566047135],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.8349923099192105],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.14532034820981404],"y":[-0.10783686474055074],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[-0.019390845645188767],"y":[0.025312818428154908],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.06938767805373888],"y":[-0.18339693378304012],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.11923818292400395],"y":[-0.04395628509418253],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.0611893774053453],"y":[-0.09991276980096211],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.2557599850403879],"y":[0.600070452837492],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.14745222778861494],"y":[0.3718801325889791],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.022397415921039915],"y":[-0.09245215241118807],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.025696474842295418],"y":[0.24203673487407903],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.13146593910692528],"y":[0.2030455095803949],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.04538927478694323],"y":[-0.37692001368209377],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.09373394098527309],"y":[-0.34876810367897054],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.06650198230964065],"y":[0.18387978682834533],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"ShiftCorrAngleUHR_target","x":[0.03886068179110729],"y":[0.38674606765086156],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.333320812860949,0.2557599850403879,null],"y":[0.7693241770073942,0.600070452837492,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.17971855629801142,0.09373394098527309,null],"y":[-0.5290525566047135,-0.34876810367897054,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.14532034820981404,-0.019390845645188767,null],"y":[-0.10783686474055074,0.02531 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="d31005db-79ab-4904-a881-300ecf7aa653" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d31005db-79ab-4904-a881-300ecf7aa653")) {                    Plotly.newPlot(                        "d31005db-79ab-4904-a881-300ecf7aa653",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","green","red","red","red","green","green","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","red","red","green","green","green","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","red","red","green","green","green","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","green","red","red","red","red","red","red","red","red","green","red","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","green","red","red","green","red","red","red","red","green","red","red","red","red","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","green","green","red","red","red","red","red","red","red","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="cb5553bc-56be-4fe9-bb8c-5fa0f7e1b513" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb5553bc-56be-4fe9-bb8c-5fa0f7e1b513")) {                    Plotly.newPlot(                        "cb5553bc-56be-4fe9-bb8c-5fa0f7e1b513",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","orange","red","red","red","red","red","red","red","red","red","red"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["PCA","Baseline","Shuffle","Laplacian","SBFE","RFE","Pearson","Spearman","Kendall","MutualInfo","ANOVA","SFFE"],"xaxis":"x","y":[0.0026862901116754996,0.0036890467398901,0.00383912671448802,0.0038482754017286876,0.0038521044180788973,0.0038524717193331977,0.0038579191269355302,0.0038579191269355302,0.0038579191269355302,0.0038681210199547874,0.003870525047282217,0.00392745977391703],"yaxis":"y","type":"bar","text":["27.18%","0.0%","-4.07%","-4.32%","-4.42%","-4.43%","-4.58%","-4.58%","-4.58%","-4.85%","-4.92%","-6.46%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["PCA","Baseline","Shuffle","Laplacian","SBFE","RFE","Pearson","Spearman","Kendall","MutualInfo","ANOVA","SFFE"],"y":[0.00032918714292158303,0.0,0.0002913887812706854,0.00032918714292158303,0.00029055260908281773,0.000291371255914112,0.0002850652437402575,0.0002952465676273393,0.0002952465676273393,0.0002881305322661587,0.0002935579794914363,0.0003166835513732336],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surfa ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="3fb5ff0e-1a0f-46d3-ba53-1572ed66c5a1" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fb5ff0e-1a0f-46d3-ba53-1572ed66c5a1")) {                    Plotly.newPlot(                        "3fb5ff0e-1a0f-46d3-ba53-1572ed66c5a1",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.0001255409699206,0.0002125,0.0008329902428786,2.91667e-05,-0.000208333,-6.045756891401e-05,0.0,0.000775,0.0005375,0.0008025399854011,-0.0004150619320659,-0.000154167],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.0002435426592876,0.0003446139742463,2.803335482211e-05,0.0001232485427139,-0.000324319632667,0.0,-0.000576621311987,0.0002002312144677,0.0003207591913932,0.0009833333333333,-8.38717088655e-05,0.0003291666666667],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.00034192297607660294,-3.109461613348685e-05,-3.109461613348685e-05,-3.109461613348685e-05,-0.00034192297607660294,-8.048055315157399e-05,-3.109461613348685e-05,-3.109461613348685e-05,-3.109461613348685e-05,-3.109461613348685e-05,-0.00034192297607660294,-0.00034192297607660294],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.00034192297607660294,-3.109461613348685e-05,-3.109461613348685e-05,-3.109461613348685e-05,-0.00034192297607660294,-8.048055315157399e-05,-3.109461613348685e-05,-3.109461613348685e-05,-3.109461613348685e-05,-3.109461613348685e-05,-0.00034192297607660294,-0.00034192297607660294],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.00034192297607660294,-3.109461613348685e-05,-3.109461613348685e-05,-3.109461613348685e-05,-0.00034192297607660294,-8.048055315157399e-05,-3.109461613348685e-05,-3.109461613348685e-05,-3.109461613348685e-05,-3.109461613348685e-05,-0.00034192297607660294,-0.00034192297607660294],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.0003478404541965574,-3.7080935726407915e-05,-3.7080935726407915e-05,-3.7080935726407915e-05,-0.0003478404541965574,-3.7080935726407915e-05,-3.7080935726407915e-05,-3.7080935726407915e-05,-3.7080935726407915e-05,-3.7080935726407915e-05,-0.0003478404541965574,-0.0003478404541965574],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.00034870507079176605,-3.6905195884173736e-05,-3.6905195884173736e-05,-3.6905195884173736e-05,-0.00034870507079176605,-3.6905195884173736e-05,-3.6905195884173736e-05,-3.6905195884173736e-05,-3.6905195884173736e-05,-3.6905195884173736e-05,-0.00034870507079176605,-0.00034870507079176605],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13" ...
# Best model set PCA breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdHRpar4_df = featureBusterMining(train_query,train_target,'MdHRpar4',test_query, test_target,'MeAE','XGB+')
# Out:
# Target feature : MdHRpar4_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="9624ec5e-8202-4216-acd9-2b9b8bb7bf64" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9624ec5e-8202-4216-acd9-2b9b8bb7bf64")) {                    Plotly.newPlot(                        "9624ec5e-8202-4216-acd9-2b9b8bb7bf64",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-4.770190598243e-07,2.046565595034e-05,8.959328938144e-06,3.866741399352e-05,9.296151381421e-06,-1.990066591452e-06,3.999459929874e-05,-2.908637822432e-05,1.45803923018e-05,9.406347179664e-05,2.866745340159e-05,9.54975091688e-06,4.394089991275e-07,1.100169071214e-05,5.987538353852e-06,4.315637435751e-05,-2.495593005762e-06,2.10340429749e-05,-2.427669341826e-05,-1.683587792227e-05,2.70220039158e-05,-2.447075551658e-05,6.181311138823e-06,-1.482203540425e-05],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-4.770190598243e-07,2.046565595034e-05,8.959328938144e-06,3.866741399352e-05,9.296151381421e-06,-1.990066591452e-06,3.999459929874e-05,-2.908637822432e-05,1.45803923018e-05,9.406347179664e-05,2.866745340159e-05,9.54975091688e-06,4.394089991275e-07,1.100169071214e-05,5.987538353852e-06,4.315637435751e-05,-2.495593005762e-06,2.10340429749e-05,-2.427669341826e-05,-1.683587792227e-05,2.70220039158e-05,-2.447075551658e-05,6.181311138823e-06,-1.482203540425e-05],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-4.770190598243e-07,2.046565595034e-05,8.959328938144e-06,3.866741399352e-05,9.296151381421e-06,-1.990066591452e-06,3.999459929874e-05,-2.908637822432e-05,1.45803923018e-05,9.406347179664e-05,2.866745340159e-05,9.54975091688e-06,4.394089991275e-07,1.100169071214e-05,5.987538353852e-06,4.315637435751e-05,-2.495593005762e-06,2.10340429749e-05,-2.427669341826e-05,-1.683587792227e-05,2.70220039158e-05,-2.447075551658e-05,6.181311138823e-06,-1.482203540425e-05],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-4.770190598243e-07,2.046565595034e-05,8.959328938144e-06,3.866741399352e-05,9.296151381421e-06,-1.990066591452e-06,3.999459929874e-05,-2.908637822432e-05,1.45803923018e-05,9.406347179664e-05,2.866745340159e-05,9.54975091688e-06,4.394089991275e-07,1.100169071214e-05,5.987538353852e-06,4.315637435751e-05,-2.495593005762e-06,2.10340429749e-05,-2.427669341826e-05,-1.683587792227e-05,2.70220039158e-05,-2.447075551658e-05,6.181311138823e-06,-1.482203540425e-05],"type":"scatter","xaxis":"x4","yaxis":"y4"}, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="41fe5add-9f95-4318-a05c-b28e6bff1e9c" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41fe5add-9f95-4318-a05c-b28e6bff1e9c")) {                    Plotly.newPlot(                        "41fe5add-9f95-4318-a05c-b28e6bff1e9c",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.5511311909470034],"y":[0.6316890827955488],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[-0.1460268979664988],"y":[-0.4636790701760633],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.6635545742837525],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.08687942232850215],"y":[0.1090276950690145],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[0.02793354404840243],"y":[0.11282873364719183],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.12223467946096979],"y":[-0.02171182359443764],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.12796233038696872],"y":[0.06095694840972303],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.04298352836762989],"y":[0.03882767943227343],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.4510691264908077],"y":[0.4915525265114756],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.3076096131470647],"y":[0.31248273841184493],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[-0.014884648890403364],"y":[-0.03426290272052932],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.16193975804272914],"y":[0.25332737234134856],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.21936454558986482],"y":[0.20630302870341652],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.2339827617747106],"y":[-0.16640062004580441],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[-0.1552896601872153],"y":[-0.2768235286833251],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.18440585396266895],"y":[0.13036478093203113],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdHRpar4_target","x":[-0.3096551285818902],"y":[-0.3844826410337086],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.5511311909470034,0.4510691264908077,null],"y":[0.6316890827955488,0.4915525265114756,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.1460268979664988,-0.1552896601872153,null],"y":[-0.4636790701760633,-0.2768235286833251,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.08687942232850215,0.02793354404840243,null],"y":[0.1090276950690145,0.11282873364719183,null ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="d5666f0b-ec00-4d98-a00e-08802ef9668b" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5666f0b-ec00-4d98-a00e-08802ef9668b")) {                    Plotly.newPlot(                        "d5666f0b-ec00-4d98-a00e-08802ef9668b",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","green","red","red","red","green","green","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","red","red","green","green","green","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","red","red","green","green","green","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","red","red","red","red","red","red","green","red","red","red","red","red","green","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","green","red","red","red","green","green","red","red","red","red","red","red","green","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","green","green","red","red","red","red","red","red","red","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="9502a6e0-8665-4169-87aa-9046b6254cb1" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9502a6e0-8665-4169-87aa-9046b6254cb1")) {                    Plotly.newPlot(                        "9502a6e0-8665-4169-87aa-9046b6254cb1",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","green","green","green","green","green","green","green","green","green","orange"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["PCA","Pearson","Spearman","Kendall","MutualInfo","ANOVA","SFFE","SBFE","RFE","Shuffle","Laplacian","Baseline"],"xaxis":"x","y":[0.000155276920910962,0.0002017211533824748,0.0002017211533824748,0.0002017211533824748,0.0002017211533824748,0.0002017211533824748,0.0002017211533824748,0.0002017211533824748,0.0002017211533824748,0.0002017211533824748,0.0002017211533824748,0.0003948604184434511],"yaxis":"y","type":"bar","text":["60.68%","48.91%","48.91%","48.91%","48.91%","48.91%","48.91%","48.91%","48.91%","48.91%","48.91%","0.0%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["PCA","Pearson","Spearman","Kendall","MutualInfo","ANOVA","SFFE","SBFE","RFE","Shuffle","Laplacian","Baseline"],"y":[1.615211960281882e-05,1.615211960281882e-05,1.615211960281882e-05,1.615211960281882e-05,1.615211960281882e-05,1.615211960281882e-05,1.615211960281882e-05,1.615211960281882e-05,1.615211960281882e-05,1.615211960281882e-05,1.615211960281882e-05,0.0],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}], ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="35d6bd95-624d-4af7-8b1c-004f721ecb24" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35d6bd95-624d-4af7-8b1c-004f721ecb24")) {                    Plotly.newPlot(                        "35d6bd95-624d-4af7-8b1c-004f721ecb24",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-6.169054095818e-05,1.895065828509e-06,-2.863026859087e-05,-2.695104489143e-05,-2.606328150238e-05,-6.659875634964e-05,-7.496403994541e-05,-8.240477695266e-05,-3.624771782156e-05,-2.029662187817e-05,2.851329641588e-05,-3.052809559988e-06],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-7.180878517385e-06,1.047613997269e-05,-2.029628935929e-06,-4.16657505511e-05,-1.084901264354e-05,7.98182996568e-06,4.167075653299e-06,-4.99461439292e-06,-1.556557743789e-05,-1.291287145354e-05,3.264552324371e-05,8.867276015137e-06],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05,1.0536961781326681e-05],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+ ...
# Best model set PCA breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdSDeflACF_df = featureBusterMining(train_query,train_target,'MdSDeflACF',test_query, test_target,'MeAE','XGB')
# Out:
# Target feature : MdSDeflACF_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="05952e40-76a5-454f-8afa-42a83196318e" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05952e40-76a5-454f-8afa-42a83196318e")) {                    Plotly.newPlot(                        "05952e40-76a5-454f-8afa-42a83196318e",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[0.128153907,0.1299526868588,0.1274673512526,0.1319902867816,0.1312149979425,0.1281114617364,0.1296284132812,0.1294051880431,0.1283034151909,0.140991963233,0.1288870708898,0.1290250863748,0.1286626317428,0.1328511091454,0.1273516880841,0.1333554095653,0.1349599147559,0.1317153403125,0.1351318968526,0.1324792140893,0.1283226540469,0.1302173168149,0.129481475944,0.132923681543],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[0.128153907,0.1299526868588,0.1274673512526,0.1319902867816,0.1312149979425,0.1281114617364,0.1296284132812,0.1294051880431,0.1283034151909,0.140991963233,0.1288870708898,0.1290250863748,0.1286626317428,0.1328511091454,0.1273516880841,0.1333554095653,0.1349599147559,0.1317153403125,0.1351318968526,0.1324792140893,0.1283226540469,0.1302173168149,0.129481475944,0.132923681543],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[0.128153907,0.1299526868588,0.1274673512526,0.1319902867816,0.1312149979425,0.1281114617364,0.1296284132812,0.1294051880431,0.1283034151909,0.140991963233,0.1288870708898,0.1290250863748,0.1286626317428,0.1328511091454,0.1273516880841,0.1333554095653,0.1349599147559,0.1317153403125,0.1351318968526,0.1324792140893,0.1283226540469,0.1302173168149,0.129481475944,0.132923681543],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[0.128153907,0.1299526868588,0.1274673512526,0.1319902867816,0.1312149979425,0.1281114617364,0.1296284132812,0.1294051880431,0.1283034151909,0.140991963233,0.1288870708898,0.1290250863748,0.1286626317428,0.1328511091454,0.1273516880841,0.1333554095653,0.1349599147559,0.1317153403125,0.1351318968526,0.1324792140893,0.1283226540469,0.1302173168149,0.129481475944,0.132923681543],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[0.128153907,0.1299526868588,0.1274673512526,0.1319902867816,0.1312149979425,0.128111461736 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="ad2d9926-bcc0-48dc-a7d6-9f1196965418" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad2d9926-bcc0-48dc-a7d6-9f1196965418")) {                    Plotly.newPlot(                        "ad2d9926-bcc0-48dc-a7d6-9f1196965418",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.49829253660860556],"y":[0.5482915641849034],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.09707144337376497],"y":[-0.5208531261155896],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7349546176915233],"y":[-0.9568606177007711],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.08942684400044155],"y":[-0.020940063822796503],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[0.017391423718227775],"y":[0.014692979882291957],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.06718252013727517],"y":[-0.1559043011901485],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.11656338561932585],"y":[-0.08041122045183315],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.04176642695056149],"y":[-0.07514839033273589],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.39884842326116376],"y":[0.41578374673204493],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.26242685069804433],"y":[0.24431154265816765],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.03447263510064944],"y":[-0.11310188183110949],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.11755816861099735],"y":[0.1735811671079455],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.17434144959381434],"y":[0.1431235998916409],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.0796796913933124],"y":[-0.3344820438641928],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.050178402825582356],"y":[-0.34838104948823445],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.18128736707901708],"y":[0.06629809434041772],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdSDeflACF_target","x":[-0.702295215077427],"y":[1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.49829253660860556,0.39884842326116376,null],"y":[0.5482915641849034,0.41578374673204493,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.09707144337376497,0.050178402825582356,null],"y":[-0.5208531261155896,-0.34838104948823445,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.08942684400044155,0.017391423718227775,null],"y":[-0.020940063822796503,0.014692 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="247e88e0-5b42-4aff-b67f-5aab2c97ffbc" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("247e88e0-5b42-4aff-b67f-5aab2c97ffbc")) {                    Plotly.newPlot(                        "247e88e0-5b42-4aff-b67f-5aab2c97ffbc",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","green","green","red","red","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","green","green","red","red","red","red","red","red","green","red","red","red","red","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","red","red","red","green","red","red","red","red","green","red","red","green","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","green","red","red","red","green","green","green","red","red","green","red","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="457f1ab3-1eff-408d-986a-773dc5e91d21" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("457f1ab3-1eff-408d-986a-773dc5e91d21")) {                    Plotly.newPlot(                        "457f1ab3-1eff-408d-986a-773dc5e91d21",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","green","green","green","green","green","green","green","green","green","orange"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["PCA","SFFE","SBFE","MutualInfo","Pearson","Shuffle","RFE","Laplacian","Spearman","Kendall","ANOVA","Baseline"],"xaxis":"x","y":[0.017197569411020838,0.020644957255419802,0.022665841783186355,0.02272457316431907,0.022954353687564585,0.028735077681606033,0.036691880526607254,0.036921507420604446,0.03733206613884653,0.03733206613884653,0.060146652897460115,0.1623621768677],"yaxis":"y","type":"bar","text":["89.41%","87.28%","86.04%","86.0%","85.86%","82.3%","77.4%","77.26%","77.01%","77.01%","62.96%","0.0%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["PCA","SFFE","SBFE","MutualInfo","Pearson","Shuffle","RFE","Laplacian","Spearman","Kendall","ANOVA","Baseline"],"y":[0.002259880114861515,0.0012185111013392573,0.0020302414793644205,0.002340428595691913,0.0027752288172393086,0.0025337985210057146,0.0022715118722705977,0.002259880114861515,0.002168635721272331,0.002168635721272331,0.002322851400615722,0.0],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="c69d5c28-c387-4e37-9b9f-a50ea312f036" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c69d5c28-c387-4e37-9b9f-a50ea312f036")) {                    Plotly.newPlot(                        "c69d5c28-c387-4e37-9b9f-a50ea312f036",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.1426,0.1426,0.1426,0.1426,0.1426,0.1317228619219,0.1426,0.1426,0.1426,0.1426,0.1426,0.1426],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.1287012069141,0.1275714661459,0.1277030130219,0.12981430575,0.1207272321563,0.1297736189801,0.1282587825974,0.1296648149998,0.1301160762841,0.1276972973437,0.1295072267582,0.1284256441027],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.13013815879821777,0.12847979366779327,0.1304742395877838,0.1291760802268982,0.13040712475776672,0.12978170812129974,0.1285506635904312,0.12931369245052338,0.1318170428276062,0.13128191232681274,0.13040712475776672,0.12910880148410797],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.13149338960647583,0.13011480867862701,0.1316576600074768,0.13011480867862701,0.13164731860160828,0.1312905102968216,0.13031715154647827,0.13055436313152313,0.13309985399246216,0.13268160820007324,0.13164731860160828,0.13067395985126495],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.13149338960647583,0.13011480867862701,0.1316576600074768,0.13011480867862701,0.13164731860160828,0.1312905102968216,0.13031715154647827,0.13055436313152313,0.13309985399246216,0.13268160820007324,0.13164731860160828,0.13067395985126495],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.1296093463897705,0.1281670480966568,0.1299668550491333,0.1296013593673706,0.13116250932216644,0.1289059966802597,0.12809599936008453,0.12781262397766113,0.13255076110363007,0.12996120750904083,0.12985573709011078,0.12880472838878632],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.13317561149597168,0.13317561149597168,0.13317561149597168,0.13317561149597168,0.13317561149597168,0.13317561149597168,0.13317561149597168,0.13317561149597168,0.13317561149597168,0.13317561149597168,0.13317561149597168,0.13317561149597168],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.13057062029838562,0.12904897332191467,0.12904897332191467,0.12904897332191467,0.13040870428085327,0.1284002661705017,0.12904897332191467,0.12904897332191467,0.13040870428085327,0.1284002661705017,0.1284002661705017,0.12904897332191467],"type":"scatter"},{"line":{"dash":"solid ...
# Best model set PCA breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdSImRotCheb1_df = featureBusterMining(train_query,train_target,'MdSImRotCheb1',test_query, test_target,'MeAE','XGB')
# Out:
# Target feature : MdSImRotCheb1_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="584fe5de-6320-4bcf-9169-cdb04360f133" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("584fe5de-6320-4bcf-9169-cdb04360f133")) {                    Plotly.newPlot(                        "584fe5de-6320-4bcf-9169-cdb04360f133",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[0.3617165435145,0.3612101156728,0.3589000541193,0.3655954067488,0.3558565181632,0.3546195799397,0.3583328753692,0.356874970973,0.3535230378498,0.3555518872472,0.3570647413362,0.345142245151,0.3600526881894,0.3543858167521,0.3561579777747,0.351400395574,0.3567362725301,0.3577262250704,0.3538523480714,0.3557273726903,0.3452170150867,0.3628695067006,0.3634795706447,0.3563551807839],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[0.3617165435145,0.3612101156728,0.3589000541193,0.3655954067488,0.3558565181632,0.3546195799397,0.3583328753692,0.356874970973,0.3535230378498,0.3555518872472,0.3570647413362,0.345142245151,0.3600526881894,0.3543858167521,0.3561579777747,0.351400395574,0.3567362725301,0.3577262250704,0.3538523480714,0.3557273726903,0.3452170150867,0.3628695067006,0.3634795706447,0.3563551807839],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[0.3617165435145,0.3612101156728,0.3589000541193,0.3655954067488,0.3558565181632,0.3546195799397,0.3583328753692,0.356874970973,0.3535230378498,0.3555518872472,0.3570647413362,0.345142245151,0.3600526881894,0.3543858167521,0.3561579777747,0.351400395574,0.3567362725301,0.3577262250704,0.3538523480714,0.3557273726903,0.3452170150867,0.3628695067006,0.3634795706447,0.3563551807839],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[0.3617165435145,0.3612101156728,0.3589000541193,0.3655954067488,0.3558565181632,0.3546195799397,0.3583328753692,0.356874970973,0.3535230378498,0.3555518872472,0.3570647413362,0.345142245151,0.3600526881894,0.3543858167521,0.3561579777747,0.351400395574,0.3567362725301,0.3577262250704,0.3538523480714,0.3557273726903,0.3452170150867,0.3628695067006,0.3634795706447,0.3563551807839],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[0.3617165435145,0.3612101156728,0.3589000541193,0.3655954067488,0.35585651 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="340e0687-c540-4f8d-8ed6-65332d58084f" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("340e0687-c540-4f8d-8ed6-65332d58084f")) {                    Plotly.newPlot(                        "340e0687-c540-4f8d-8ed6-65332d58084f",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.45816056141449163],"y":[0.639494983966496],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.11985529923937882],"y":[-0.47506765714061056],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7435529629352137],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.1464432340841217],"y":[0.027750422619393533],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[-0.047409310309846846],"y":[0.08160754598299925],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.09622350926332818],"y":[-0.11116695484870459],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.0771466505975676],"y":[-0.02175674838237538],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.15012298027928797],"y":[-0.04667295842220979],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.3575230192735297],"y":[0.5011914339846235],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.2217511803403019],"y":[0.3200975805260648],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.004517189595341717],"y":[-0.05910544059261998],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.12373273041757732],"y":[0.21292534265831467],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.07137520813220115],"y":[0.24768909561401248],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.08228160099125816],"y":[-0.30039776633687076],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.05130162864633326],"y":[-0.3029001025260394],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.14704076326056614],"y":[0.13501238531332946],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdSImRotCheb1_target","x":[-0.21207733185909772],"y":[0.15129883758419696],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.45816056141449163,0.3575230192735297,null],"y":[0.639494983966496,0.5011914339846235,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.11985529923937882,0.05130162864633326,null],"y":[-0.47506765714061056,-0.3029001025260394,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.1464432340841217,-0.047409310309846846,null],"y":[0.027750422619393533,0.08160754 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="026524a3-dd38-4c58-901d-8957b3a4ff7f" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("026524a3-dd38-4c58-901d-8957b3a4ff7f")) {                    Plotly.newPlot(                        "026524a3-dd38-4c58-901d-8957b3a4ff7f",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","green","green","red","red","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","green","red","green","green","green","red","green","green","red","red","red","green","red","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","green","red","red","red","red","red","red","red","red","red","red","red","green","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","green","green","red","red","green","red","red","red","red","green","red","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","green","green","green","red","red","red","red","red","green","green","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="f9e6becc-cc4e-416f-ba79-faa81583bd0c" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9e6becc-cc4e-416f-ba79-faa81583bd0c")) {                    Plotly.newPlot(                        "f9e6becc-cc4e-416f-ba79-faa81583bd0c",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","green","green","green","green","green","green","green","green","green","orange"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["ANOVA","Laplacian","PCA","RFE","Pearson","SFFE","Spearman","Kendall","MutualInfo","SBFE","Shuffle","Baseline"],"xaxis":"x","y":[0.057053656265148134,0.057053656265148134,0.06084082853896178,0.06153691645294945,0.06599448419309895,0.07179456716308874,0.07187746298415221,0.07187746298415221,0.07475741040808714,0.07897330160767357,0.08109951849610131,0.20308833175520014],"yaxis":"y","type":"bar","text":["71.91%","71.91%","70.04%","69.7%","67.5%","64.65%","64.61%","64.61%","63.19%","61.11%","60.07%","0.0%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["ANOVA","Laplacian","PCA","RFE","Pearson","SFFE","Spearman","Kendall","MutualInfo","SBFE","Shuffle","Baseline"],"y":[0.002998107294742471,0.002152345042074492,0.002152345042074492,0.0034881286596554484,0.003432013115733943,0.003322191733000357,0.0030556781460526947,0.0030556781460526947,0.0036604068946289683,0.0018062353246740086,0.0029066323142407555,0.0],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="b8748caf-93fc-43d2-9bd1-52cd319015ea" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8748caf-93fc-43d2-9bd1-52cd319015ea")) {                    Plotly.newPlot(                        "b8748caf-93fc-43d2-9bd1-52cd319015ea",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.357,0.2681,0.357,0.357,0.2681,0.357,0.357,0.357,0.357,0.357,0.357,0.357],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.357,0.3565432882549,0.3637689039166,0.3622749851604,0.3409909527715,0.363021848382,0.3524280587548,0.368200347508,0.3571895590999,0.3524862105828,0.3558301395825,0.359042855582],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.3600497245788574,0.3632839620113373,0.3591272532939911,0.35952523350715637,0.35382378101348877,0.35165706276893616,0.3597571849822998,0.3590233623981476,0.3557416796684265,0.35446226596832275,0.3538263142108917,0.35636165738105774],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.36340540647506714,0.35942593216896057,0.3627815246582031,0.3617244362831116,0.3569968640804291,0.3556726276874542,0.3622682988643646,0.3627815246582031,0.364417165517807,0.3630714416503906,0.3564140796661377,0.35500234365463257],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.36340540647506714,0.35942593216896057,0.3627815246582031,0.3617244362831116,0.3569968640804291,0.3556726276874542,0.3622682988643646,0.3627815246582031,0.364417165517807,0.3630714416503906,0.3564140796661377,0.35500234365463257],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.3598485589027405,0.35735782980918884,0.35735782980918884,0.35735782980918884,0.36185935139656067,0.36206507682800293,0.35735782980918884,0.35735782980918884,0.36185935139656067,0.36206507682800293,0.36206507682800293,0.35735782980918884],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.357126384973526,0.35353901982307434,0.357126384973526,0.357126384973526,0.35353901982307434,0.357126384973526,0.357126384973526,0.357126384973526,0.357126384973526,0.357126384973526,0.357126384973526,0.357126384973526],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.35419535636901855,0.3535346984863281,0.35419535636901855,0.35419535636901855,0.3535346984863281,0.35419535636901855,0.35419535636901855,0.35419535636901855,0.35419535636901855,0.35419535636901855,0.35419535636901855,0.35419535636901855],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"pink","size":10,"symbol":"x"},"mode":"mark ...
# Best model set ANOVA breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdSShiftTube3_df = featureBusterMining(train_query,train_target,'MdSShiftTube3',test_query, test_target,'MeAE','XGB')
# Out:
# Target feature : MdSShiftTube3_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="a8394695-33e8-4d25-a628-ae723c0aa815" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8394695-33e8-4d25-a628-ae723c0aa815")) {                    Plotly.newPlot(                        "a8394695-33e8-4d25-a628-ae723c0aa815",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-26.83227366691,-54.68965656511,-47.50529087548,30.25097052969,38.88184732118,-17.77432746305,90.69935004948,14.20816813286,-19.70654912325,-15.81271944019,-38.26220129051,47.53028744857,13.41934023604,-89.66459918434,-5.981913814789,-39.1952624981,-34.46437948309,-81.08160426319,51.7210231703,-1.412800416178,25.8382713909,-65.70163753494,-43.76061783344,-28.32970384445],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-26.83227366691,-54.68965656511,-47.50529087548,30.25097052969,38.88184732118,-17.77432746305,90.69935004948,14.20816813286,-19.70654912325,-15.81271944019,-38.26220129051,47.53028744857,13.41934023604,-89.66459918434,-5.981913814789,-39.1952624981,-34.46437948309,-81.08160426319,51.7210231703,-1.412800416178,25.8382713909,-65.70163753494,-43.76061783344,-28.32970384445],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-26.83227366691,-54.68965656511,-47.50529087548,30.25097052969,38.88184732118,-17.77432746305,90.69935004948,14.20816813286,-19.70654912325,-15.81271944019,-38.26220129051,47.53028744857,13.41934023604,-89.66459918434,-5.981913814789,-39.1952624981,-34.46437948309,-81.08160426319,51.7210231703,-1.412800416178,25.8382713909,-65.70163753494,-43.76061783344,-28.32970384445],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-26.83227366691,-54.68965656511,-47.50529087548,30.25097052969,38.88184732118,-17.77432746305,90.69935004948,14.20816813286,-19.70654912325,-15.81271944019,-38.26220129051,47.53028744857,13.41934023604,-89.66459918434,-5.981913814789,-39.1952624981,-34.46437948309,-81.08160426319,51.7210231703,-1.412800416178,25.8382713909,-65.70163753494,-43.76061783344,-28.32970384445],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[-26.83227366691,-54.68965656511,-47.50529087548,30.25097052969,38.88184732118,-17.77432746305,90.699350049 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="4c389cf0-fee3-49eb-894b-3a7939b57a11" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c389cf0-fee3-49eb-894b-3a7939b57a11")) {                    Plotly.newPlot(                        "4c389cf0-fee3-49eb-894b-3a7939b57a11",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.5681637273896086],"y":[0.6448998732271518],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[-0.12884351619569107],"y":[-0.4512272600947625],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7096573577374435],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.03864486161027468],"y":[0.04146261113013516],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[0.04008675296108479],"y":[0.09793960542605812],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.1265697348283807],"y":[-0.04201271521644154],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.09920955479582179],"y":[0.06264731883637217],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.04391879869503063],"y":[-0.03599401784199587],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.46336278802426817],"y":[0.5042754906192861],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.31818848387594917],"y":[0.3214608335337709],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.02361380648108067],"y":[-0.04174959744321707],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.16607112563686646],"y":[0.25493265009416427],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.2257843664962975],"y":[0.21412892047717308],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.28437423864362527],"y":[-0.1977158607357676],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[-0.11464344350504492],"y":[-0.26050898674019857],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.20919303265053668],"y":[0.13384059177288332],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdSShiftTube3_target","x":[-0.4686025775043798],"y":[-0.2463794570446117],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.5681637273896086,0.46336278802426817,null],"y":[0.6448998732271518,0.5042754906192861,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.12884351619569107,-0.11464344350504492,null],"y":[-0.4512272600947625,-0.26050898674019857,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.03864486161027468,0.04008675296108479,null],"y":[0.04146261113013516,0.0979396054 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="ee462b1d-1253-45ac-a09b-a9ea7677baad" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee462b1d-1253-45ac-a09b-a9ea7677baad")) {                    Plotly.newPlot(                        "ee462b1d-1253-45ac-a09b-a9ea7677baad",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","green","green","red","red","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","green","red","green","green","red","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","green","red","green","green","red","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","green","red","red","red","red","green","red","red","red","red","green","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","red","green","green","red","red","red","red","red","red","red","red","green","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","green","red","red","red","green","green","red","red","green","red","red","green","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="d4a0d5c9-037a-480b-9be3-8bcc17b0af40" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4a0d5c9-037a-480b-9be3-8bcc17b0af40")) {                    Plotly.newPlot(                        "d4a0d5c9-037a-480b-9be3-8bcc17b0af40",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","green","green","green","green","orange","red","red","red","red","red"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["SBFE","Pearson","Spearman","Kendall","Shuffle","MutualInfo","Baseline","Laplacian","ANOVA","PCA","RFE","SFFE"],"xaxis":"x","y":[360.8467136602426,406.4227403545345,407.4743005001645,407.4743005001645,423.7924095356564,454.1611462795834,498.703444220694,529.0158168041805,537.1460221166815,547.0943959333296,550.1013537609676,606.6031296606268],"yaxis":"y","type":"bar","text":["27.64%","18.5%","18.29%","18.29%","15.02%","8.93%","0.0%","-6.08%","-7.71%","-9.7%","-10.31%","-21.64%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["SBFE","Pearson","Spearman","Kendall","Shuffle","MutualInfo","Baseline","Laplacian","ANOVA","PCA","RFE","SFFE"],"y":[31.755354535863024,28.726705824956365,37.54027880860529,37.54027880860529,36.73799692352316,32.05818108774903,0.0,35.080953265175594,28.06983613482811,35.080953265175594,29.62046230575281,29.95022317003946],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="ea037432-a9e9-4ce8-be89-909b82a0e714" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea037432-a9e9-4ce8-be89-909b82a0e714")) {                    Plotly.newPlot(                        "ea037432-a9e9-4ce8-be89-909b82a0e714",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[10.66195438508,-29.81742449154,-114.7716559021,18.27300134536,47.68887636462,-20.91807403464,5.93601030833,70.34944332008,82.99933930197,17.35707453113,22.04106814285,-41.32939237551],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-12.15732158851,-100.327584048,-35.37312213623,-52.65053405403,10.37591990891,-18.72677291333,29.19090395373,35.9579770838,8.791514512955,26.47612549155,50.61072386551,4.675398219079],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-33.65391540527344,-44.14340591430664,-14.30922794342041,-52.166473388671875,-34.04405212402344,-11.34230899810791,-25.586334228515625,-4.631436347961426,-9.006430625915527,-14.58984661102295,-26.13896369934082,-19.733922958374023],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-30.582744598388672,-35.50469207763672,-7.791263580322266,-33.45511245727539,-25.0699462890625,-25.0699462890625,-28.523080825805664,-7.791263580322266,0.944066047668457,-7.791263580322266,-18.432519912719727,-18.362960815429688],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-30.582744598388672,-35.50469207763672,-7.791263580322266,-33.45511245727539,-25.0699462890625,-25.0699462890625,-28.523080825805664,-7.791263580322266,0.944066047668457,-7.791263580322266,-18.432519912719727,-18.362960815429688],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-24.755996704101562,-24.755996704101562,-24.755996704101562,-24.755996704101562,-24.755996704101562,-24.755996704101562,-24.755996704101562,-24.755996704101562,-6.835453987121582,-24.755996704101562,-24.755996704101562,-24.755996704101562],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-35.54331970214844,-35.54331970214844,-35.54331970214844,-35.54331970214844,-35.54331970214844,-35.54331970214844,-35.54331970214844,-35.54331970214844,-35.54331970214844,-35.54331970214844,-35.54331970214844,-35.54331970214844],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-48.09917449951172,-43.20281219482422,-44.84521484375,-44.84521484375,-43.20281219482422,-43.20281219482422,-43.20281219482422,-44.84521484375,-43.20281219482422,-44.84521484375,-43.20281219482422,-43.20281219482422],"type":"s ...
# Best model set SBFE breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdACRotUpp_df = featureBusterMining(train_query,train_target,'MdACRotUpp',test_query, test_target,'MeAE','XGB+')
# Out:
# Target feature : MdACRotUpp_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="86d6998f-d039-4c92-aef4-ac7c1069b06f" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86d6998f-d039-4c92-aef4-ac7c1069b06f")) {                    Plotly.newPlot(                        "86d6998f-d039-4c92-aef4-ac7c1069b06f",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.0009198041160118,-0.00098,-0.00098,0.003836067220002,0.0,-0.00098,-0.00098,-0.00098,-0.0138018071681,-0.00098,0.008,0.002,0.002,0.008755290424976,-0.00098,0.005659856479549,0.003697754677755,-0.00098,0.016],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.0009198041160118,-0.00098,-0.00098,0.003836067220002,0.0,-0.00098,-0.00098,-0.00098,-0.0138018071681,-0.00098,0.008,0.002,0.002,0.008755290424976,-0.00098,0.005659856479549,0.003697754677755,-0.00098,0.016],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.0009198041160118,-0.00098,-0.00098,0.003836067220002,0.0,-0.00098,-0.00098,-0.00098,-0.0138018071681,-0.00098,0.008,0.002,0.002,0.008755290424976,-0.00098,0.005659856479549,0.003697754677755,-0.00098,0.016],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.0009198041160118,-0.00098,-0.00098,0.003836067220002,0.0,-0.00098,-0.00098,-0.00098,-0.0138018071681,-0.00098,0.008,0.002,0.002,0.008755290424976,-0.00098,0.005659856479549,0.003697754677755,-0.00098,0.016],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.0009198041160118,-0.00098,-0.00098,0.003836067220002,0.0,-0.00098,-0.00098,-0.00098,-0.0138018071681,-0.00098,0.008,0.002,0.002,0.008755290424976,-0.00098,0.005659856479549,0.003697754677755,-0.00098,0.016],"type":"scatter","xaxis":"x5","yaxis":"y5"},{"mode":"markers","showlegend":false,"x":[-20.0,-20.0,-10.0,-20.0,-20.0,-20.0,-20.0,-20.0,-10.0,-20.0,-10.0,-20.0,-20.0,-20.0,-20.0,-10.0,-20.0,-20.0,-20.0,-20.0,-10.0,-10.0,-20.0,-10.0],"y":[-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.0009198041160118,-0.00098,-0.00098,0.003836 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="b03e2c32-77a6-4110-8fcc-6103f905862a" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b03e2c32-77a6-4110-8fcc-6103f905862a")) {                    Plotly.newPlot(                        "b03e2c32-77a6-4110-8fcc-6103f905862a",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.13690052265625227],"y":[0.6453396445020425],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.1558795631643188],"y":[-0.5001460632336309],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7559710704253256],"y":[-1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.12342816749478834],"y":[0.021205959792152538],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[-0.012555988862713563],"y":[0.08093795122254918],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.03269290550031948],"y":[-0.01141303695279506],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.08404407946384375],"y":[-0.0797826541989543],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.1399717931260781],"y":[-0.04356875045937543],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.11174792384583924],"y":[0.45128332130709603],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.20350762042787537],"y":[0.3011536474453315],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.03132896597700149],"y":[-0.07153268643814671],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.12619194138622433],"y":[0.1803149096509813],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.10642082204433356],"y":[0.23642605834048633],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.012492358854942546],"y":[-0.2369100677299404],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.09198588044359533],"y":[-0.31693657870450953],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.18461905385888508],"y":[0.11263025163917931],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdACRotUpp_target","x":[0.012574069923685854],"y":[0.23099809381753383],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.13690052265625227,0.11174792384583924,null],"y":[0.6453396445020425,0.45128332130709603,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.1558795631643188,0.09198588044359533,null],"y":[-0.5001460632336309,-0.31693657870450953,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.12342816749478834,-0.012555988862713563,null],"y":[0.021205959792152538,0.0809379 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="7b0d1d63-0ccd-4bec-a5ff-25f4a07657cf" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b0d1d63-0ccd-4bec-a5ff-25f4a07657cf")) {                    Plotly.newPlot(                        "7b0d1d63-0ccd-4bec-a5ff-25f4a07657cf",                        [{"cells":{"align":"left","fill":{"color":[["red","green","green","red","red","green","red","red","green","green","green","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","red","red","green","green","green","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","red","red","green","green","green","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","green","red","red","red","red","red","green","red","green","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","green","red","red","green","red","red","green","green","red","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","red","green","green","green","red","red","green","red","red","red","green","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="b12b40a5-24d4-4b02-a73b-185e5fd9cbd1" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b12b40a5-24d4-4b02-a73b-185e5fd9cbd1")) {                    Plotly.newPlot(                        "b12b40a5-24d4-4b02-a73b-185e5fd9cbd1",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","orange","red","red","red","red","red","red","red","red","red","red"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["PCA","Baseline","SFFE","SBFE","Shuffle","Laplacian","ANOVA","MutualInfo","Pearson","Spearman","Kendall","RFE"],"xaxis":"x","y":[0.021721667799054004,0.023721667799054002,0.040228376635311466,0.04561660505590803,0.04814295132904622,0.053159696054606055,0.05349565414242289,0.05473418115168653,0.07396681797283805,0.08237874432962546,0.08237874432962546,0.08851626265823997],"yaxis":"y","type":"bar","text":["8.43%","0.0%","-69.58%","-92.3%","-102.95%","-124.1%","-125.51%","-130.73%","-211.81%","-247.27%","-247.27%","-273.15%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["PCA","Baseline","SFFE","SBFE","Shuffle","Laplacian","ANOVA","MutualInfo","Pearson","Spearman","Kendall","RFE"],"y":[0.003308853345762327,0.0,0.003441853089192882,0.0032970098352365796,0.0026891905648160444,0.003308853345762327,0.0031630151930166325,0.0027126339809066375,0.0036922677634314946,0.003270655088715066,0.003270655088715066,0.0035781829795322358],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface", ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="19bd9bf8-40e8-48f9-a4b0-22847d6663c8" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19bd9bf8-40e8-48f9-a4b0-22847d6663c8")) {                    Plotly.newPlot(                        "19bd9bf8-40e8-48f9-a4b0-22847d6663c8",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-0.002,-0.00098,-0.00098,0.002,0.005377368225766,-0.00098,0.005675398267484,-0.00098,-0.00098,0.005728901305804,-0.00098,-0.00098],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.00976213626563549,0.003144709626212716,0.006372518837451935,0.005535900592803955,0.009888381697237492,0.0048940409906208515,0.005402480252087116,0.005922372918576002,0.006499811541289091,0.006245307624340057,0.007272902876138687,0.012402086518704891],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.012191088870167732,0.0008626714115962386,0.006811264902353287,0.007223429158329964,0.010762798599898815,0.00799807719886303,0.0073570432141423225,0.007020389661192894,0.0061697703786194324,0.007018142845481634,0.006029301788657904,0.012856434099376202],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.012191088870167732,0.0008626714115962386,0.006811264902353287,0.007223429158329964,0.010762798599898815,0.00799807719886303,0.0073570432141423225,0.007020389661192894,0.0061697703786194324,0.007018142845481634,0.006029301788657904,0.012856434099376202],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.005182085558772087,0.002894143108278513,0.005182085558772087,0.005182085558772087,0.002894143108278513,0.005182085558772087,0.005182085558772087,0.005182085558772087,0.005182085558772087,0.005182085558772087,0.005182085558772087,0.005182085558772087],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.007149001583456993,0.0014506205916404724,0.0026718818116933107,0.0026718818116933107,0.0014506205916404724,0.0026718818116933107,0.0026718818116933107,0.007149001583456993,0.0075403377413749695,0.0026718818116933107,0.0026718818116933107,0.0026718818116933107],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[0.0023387151304632425,0.002570881275460124,0.0024617526214569807,0.002059727907180786,0.0024315451737493277,0.0024617526214569807,0.0024617526214569807,0.002059727907180786,0.003825243329629302,0.0024617526214569807,0.0023387151304632425,0.003825 ...
# Best model set PCA breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
MdSImRotCheb0_df = featureBusterMining(train_query,train_target,'MdSImRotCheb0',test_query, test_target,'MeAE','XGB+')
# Out:
# Target feature : MdSImRotCheb0_target
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="2fa8c2cc-4eea-4a61-8775-76664b0bc3c5" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fa8c2cc-4eea-4a61-8775-76664b0bc3c5")) {                    Plotly.newPlot(                        "2fa8c2cc-4eea-4a61-8775-76664b0bc3c5",                        [{"mode":"markers","showlegend":false,"x":[-180.4921232586,0.0,-143.987511271,-247.3695620841,-156.7539708738,-140.638440761,-149.3997838942,-124.0,-157.8640161103,-153.9696604078,-139.7602813523,-153.68,-145.6651869584,-156.8949341643,-154.6435233697,-144.8335408392,-159.5757859578,-142.12,-181.3036630356,-181.3036630356,-152.2041290084,-161.7715484277,-155.763986272,-132.0686967871],"y":[-1.610594209464,-1.613985729988,-1.608991533199,-1.609978852666,-1.595627814184,-1.608432184022,-1.600094263416,-1.610784530841,-1.603551439772,-1.607278156937,-1.610346972246,-1.607301625531,-1.613122327039,-1.611184709586,-1.588134008148,-1.615446499744,-1.60576962799,-1.610372228389,-1.610756484764,-1.608164478467,-1.610677193038,-1.61316941903,-1.610190532215,-1.6156286976],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","showlegend":false,"x":[-9.852483014156e-05,-5.39657e-05,-0.0007781107221167,-0.000111973360031,0.0,8.4719e-05,-2.209837856239e-05,0.000176566,0.0001531700809466,0.0,0.0005839457717683,-9.69397e-05,-1.63081e-05,0.0,9.62835e-05,-6.873245087624e-05,1.67616e-05,-0.000131474,5.76262e-05,5.76262e-05,4.633926918423e-05,-3.766573818577e-05,0.000122326,-2.474360423802e-05],"y":[-1.610594209464,-1.613985729988,-1.608991533199,-1.609978852666,-1.595627814184,-1.608432184022,-1.600094263416,-1.610784530841,-1.603551439772,-1.607278156937,-1.610346972246,-1.607301625531,-1.613122327039,-1.611184709586,-1.588134008148,-1.615446499744,-1.60576962799,-1.610372228389,-1.610756484764,-1.608164478467,-1.610677193038,-1.61316941903,-1.610190532215,-1.6156286976],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"markers","showlegend":false,"x":[-0.05272292344079,0.00152136,-0.0008584454048142,-0.001187108429494,0.0,0.0216396,0.01703752153341,0.00138716,-0.01446212624883,-0.004218639218509,-0.03307518377438,-0.0237379,0.000507286,0.0,-0.00498953,0.06135827997252,-0.0114468,-0.000501666,-0.0195534,-0.0195534,0.01228743800594,-0.003094950764744,-0.0247249,-0.003883838057216],"y":[-1.610594209464,-1.613985729988,-1.608991533199,-1.609978852666,-1.595627814184,-1.608432184022,-1.600094263416,-1.610784530841,-1.603551439772,-1.607278156937,-1.610346972246,-1.607301625531,-1.613122327039,-1.611184709586,-1.588134008148,-1.615446499744,-1.60576962799,-1.610372228389,-1.610756484764,-1.608164478467,-1.610677193038,-1.61316941903,-1.610190532215,-1.6156286976],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"markers","showlegend":false,"x":[-0.00215,-0.00215,-0.00215,-0.00215,0.0,-0.00215,-0.00215,0.0,-0.00215,-0.00215,-0.00215,0.0,-0.00215,0.0,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.00215,-0.01366666666667,-0.00215,-0.00215],"y":[-1.610594209464,-1.613985729988,-1.608991533199,-1.609978852666,-1.595627814184,-1.608432184022,-1.600094263416,-1.610784530841,-1.603551439772,-1.607278156937,-1.610346972246,-1.607301625531,-1.613122327039,-1.611184709586,-1.588134008148,-1.615446499744,-1.60576962799,-1.610372228389,-1.610756484764,-1.608164478467,-1.610677193038,-1.61316941903,-1.610190532215,-1.6156286976],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"markers","showlegend":false,"x":[-0.00098,-0.00098,-0.00098,-0.00098,0.0,-0.00098,-0.00098,0.0,-0.00098,-0.00098,-0.00098,0.0,-0.00098,0.0,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.00098,-0.004,-0.00098,-0.00098],"y":[-1.610594209464,-1.613985729988,-1.608991533199,-1.609978852666,-1.59562781418 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="bb84cf12-90ad-4226-80d0-206f46fe2313" class="plotly-graph-div" style="height:500px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb84cf12-90ad-4226-80d0-206f46fe2313")) {                    Plotly.newPlot(                        "bb84cf12-90ad-4226-80d0-206f46fe2313",                        [{"marker":{"color":"blue","size":10},"mode":"markers","name":"TLD.Push","x":[0.49829253660860556],"y":[0.5482915641849034],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"AlignCorrAngleUHR","x":[0.09707144337376497],"y":[-0.5208531261155896],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"CorrStigUppYUHR","x":[-0.7349546176915233],"y":[-0.9568606177007711],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotLow","x":[-0.08942684400044155],"y":[-0.020940063822796503],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdACRotUpp","x":[0.017391423718227775],"y":[0.014692979882291957],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdCompUHRRem","x":[-0.06718252013727517],"y":[-0.1559043011901485],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflACF","x":[-0.11656338561932585],"y":[-0.08041122045183315],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdDeflDC1","x":[-0.04176642695056149],"y":[-0.07514839033273589],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRSatPar1","x":[0.39884842326116376],"y":[0.41578374673204493],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdHRpar4","x":[0.26242685069804433],"y":[0.24431154265816765],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSDeflACF","x":[0.03447263510064944],"y":[-0.11310188183110949],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb0","x":[0.11755816861099735],"y":[0.1735811671079455],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSImRotCheb1","x":[0.17434144959381434],"y":[0.1431235998916409],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdSShiftTube3","x":[-0.0796796913933124],"y":[-0.3344820438641928],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"MdTLDAlign","x":[0.050178402825582356],"y":[-0.34838104948823445],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"ShiftCorrAngleUHR","x":[0.18128736707901708],"y":[0.06629809434041772],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"red","size":10},"mode":"markers","name":"MdSImRotCheb0_target","x":[-0.702295215077427],"y":[1.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.49829253660860556,0.39884842326116376,null],"y":[0.5482915641849034,0.41578374673204493,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[0.09707144337376497,0.050178402825582356,null],"y":[-0.5208531261155896,-0.34838104948823445,null],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"none","line":{"color":"gray"},"mode":"lines","x":[-0.08942684400044155,0.017391423718227775,null],"y":[-0.020940063822796503,0.014 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="a9ee00ae-843c-40ce-9e74-45b5e7cd98f7" class="plotly-graph-div" style="height:700px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9ee00ae-843c-40ce-9e74-45b5e7cd98f7")) {                    Plotly.newPlot(                        "a9ee00ae-843c-40ce-9e74-45b5e7cd98f7",                        [{"cells":{"align":"left","fill":{"color":[["green","green","green","red","red","green","green","red","red","green","red","green","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Pearson"]},"type":"table","domain":{"x":[0.0,0.07438016528925619],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","green","red","green","green","red","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Spearman"]},"type":"table","domain":{"x":[0.09256198347107437,0.16694214876033056],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["green","red","green","red","green","green","green","red","green","green","red","red","red","green","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["Kendall"]},"type":"table","domain":{"x":[0.18512396694214875,0.25950413223140495],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","green","green","red","red","red","red","red","red","green","red","red","red","red","red","red"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["MutualInformation"]},"type":"table","domain":{"x":[0.27768595041322314,0.3520661157024793],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","red","green","green","red","red","red","red","red","red","red","red","green","green"]]},"font":{"color":"black","size":12},"height":30,"values":[["TLD.Push","AlignCorrAngleUHR","CorrStigUppYUHR","MdACRotLow","MdACRotUpp","MdCompUHRRem","MdDeflACF","MdDeflDC1","MdHRSatPar1","MdHRpar4","MdSDeflACF","MdSImRotCheb0","MdSImRotCheb1","MdSShiftTube3","MdTLDAlign","ShiftCorrAngleUHR"]]},"header":{"align":"center","fill":{"color":"lightgrey"},"font":{"color":"black","size":12},"values":["ANOVA"]},"type":"table","domain":{"x":[0.3702479338842975,0.44462809917355367],"y":[0.0,1.0]}},{"cells":{"align":"left","fill":{"color":[["red","red","red","green","green","red","green","green","red","red","green","red","red","red","red","red"]]},"font":{"color":"black","size":12},"h ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="2f12d672-06b3-4195-bb31-39e6a73a95cd" class="plotly-graph-div" style="height:400px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f12d672-06b3-4195-bb31-39e6a73a95cd")) {                    Plotly.newPlot(                        "2f12d672-06b3-4195-bb31-39e6a73a95cd",                        [{"alignmentgroup":"True","hovertemplate":"ID_ref=%{x}<br>Align_total=%{y}<extra></extra>","legendgroup":"","marker":{"color":["green","green","orange","red","red","red","red","red","red","red","red","red"],"opacity":1,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"outside","x":["SFFE","PCA","Baseline","MutualInfo","Shuffle","Spearman","Kendall","Pearson","SBFE","Laplacian","ANOVA","RFE"],"xaxis":"x","y":[0.12795252249307532,0.13073143599100012,0.13939835514900012,0.1489537482873835,0.15222449983923592,0.1576758523445998,0.1576758523445998,0.15866349526367052,0.15897078590863623,0.16248757915967382,0.16306061821454443,0.1662071534570948],"yaxis":"y","type":"bar","text":["8.21%","6.22%","0.0%","-6.85%","-9.2%","-13.11%","-13.11%","-13.82%","-14.04%","-16.56%","-16.97%","-19.23%"]},{"line":{"color":"black"},"mode":"lines+markers","name":"MeAE","x":["SFFE","PCA","Baseline","MutualInfo","Shuffle","Spearman","Kendall","Pearson","SBFE","Laplacian","ANOVA","RFE"],"y":[0.003257410070130917,0.003769983706193858,0.0,0.003976447489657013,0.0028209107881917994,0.003015000681333128,0.003015000681333128,0.0045238907166583004,0.0028094014256390873,0.003769983706193858,0.00447805914288113,0.0026858014977486264],"type":"scatter","showlegend":false}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outline ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="8f307131-aa32-4735-a12a-77018575e3f4" class="plotly-graph-div" style="height:550px; width:1900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f307131-aa32-4735-a12a-77018575e3f4")) {                    Plotly.newPlot(                        "8f307131-aa32-4735-a12a-77018575e3f4",                        [{"line":{"dash":"dot"},"marker":{"color":"red","size":10,"symbol":"x"},"mode":"markers+lines","name":"Test_Query","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.62,-1.5769,-1.62,-1.62,-1.5769,-1.62,-1.62,-1.62,-1.62,-1.62,-1.62,-1.62],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"green","size":10,"symbol":"star"},"mode":"markers+lines","name":"Test_Target","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.62,-1.617975796307,-1.62501665283,-1.586758083187,-1.57254419675,-1.609281781358,-1.607161965575,-1.621316880619,-1.611571970739,-1.614666540421,-1.628058857958,-1.610985294535],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"blue","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Pearson","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.6109256744384766,-1.610142707824707,-1.604466199874878,-1.608332633972168,-1.6103572845458984,-1.6098048686981201,-1.6093988418579102,-1.6023249626159668,-1.606840968132019,-1.6053606271743774,-1.6035780906677246,-1.6094368696212769],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"black","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Spearman","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.6087499856948853,-1.6103588342666626,-1.606155276298523,-1.6099357604980469,-1.6095927953720093,-1.608410358428955,-1.6085346937179565,-1.6035215854644775,-1.6075642108917236,-1.6057199239730835,-1.60233736038208,-1.6099793910980225],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"orange","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Kendall","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.6087499856948853,-1.6103588342666626,-1.606155276298523,-1.6099357604980469,-1.6095927953720093,-1.608410358428955,-1.6085346937179565,-1.6035215854644775,-1.6075642108917236,-1.6057199239730835,-1.60233736038208,-1.6099793910980225],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"brown","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_MutualInfo","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.612830400466919,-1.6124358177185059,-1.6106221675872803,-1.609621524810791,-1.613221526145935,-1.6089261770248413,-1.610230803489685,-1.602928638458252,-1.612026572227478,-1.608959436416626,-1.5983556509017944,-1.611616611480713],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"yellow","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_ANOVA","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.6116523742675781,-1.6114747524261475,-1.6006096601486206,-1.6102925539016724,-1.6071029901504517,-1.611376404762268,-1.6105966567993164,-1.6029815673828125,-1.6065181493759155,-1.6006096601486206,-1.6075059175491333,-1.613168716430664],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"purple","size":10,"symbol":"x"},"mode":"markers+lines","name":"Pred_Start_Sffe","x":["8","10","12","13","16","17","19","22","25","30","32","33"],"y":[-1.6135889291763306,-1.6067472696304321,-1.6135889291763306,-1.6135889291763306,-1.6067472696304321,-1.6128100156784058,-1.6135889291763306,-1.6135889291763306,-1.6135889291763306,-1.6135889291763306,-1.6135889291763306,-1.6135889291763306],"type":"scatter"},{"line":{"dash":"solid"},"marker":{"color":"pink","size ...
# Best model set SFFE breakdown
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
df_models_results = pd.DataFrame(columns=train_target.columns, index=[0])

df_models_results.loc[0, "MdTLDAlign"] = MdTLDAlign_df[7].iloc[0,0]
df_models_results.loc[0, "MdDeflACF"] = MdDeflACF_df[7].iloc[0,0]
df_models_results.loc[0, "TLD.Push"] = TLDPush_df[7].iloc[0,0]
df_models_results.loc[0, "CorrStigUppYUHR"] = CorrStigUppYUHR_df[7].iloc[0,0]
df_models_results.loc[0, "MdACRotLow"] = MdACRotLow_df[7].iloc[0,0]
df_models_results.loc[0, "MdACRotUpp"] = MdACRotUpp_df[7].iloc[0,0]
df_models_results.loc[0, "MdCompUHRRem"] = MdCompUHRRem_df[7].iloc[0,0]
df_models_results.loc[0, "MdHRSatPar1"] = MdHRSatPar1_df[7].iloc[0,0]
df_models_results.loc[0, "MdSDeflACF"] = MdSDeflACF_df[7].iloc[0,0]
df_models_results.loc[0, "MdSImRotCheb0"] = MdSImRotCheb0_df[7].iloc[0,0]
df_models_results.loc[0, "MdSImRotCheb1"] = MdSImRotCheb1_df[7].iloc[0,0]
df_models_results.loc[0, "MdSShiftTube3"] = MdSShiftTube3_df[7].iloc[0,0]
df_models_results.loc[0, "ShiftCorrAngleUHR"] = ShiftCorrAngleUHR_df[7].iloc[0,0]
df_models_results.loc[0, "AlignCorrAngleUHR"] = AlignCorrAngleUHR_df[7].iloc[0,0]
df_models_results.loc[0, "MdDeflDC1"] = MdDeflDC1_df[7].iloc[0,0]
df_models_results.loc[0, "MdHRpar4"] = MdHRpar4_df[7].iloc[0,0]

sorted_df_score = df_models_results.sort_values(by=0, axis=1, ascending=False)

# %%
# Display results of alignment reduction

x_values = sorted_df_score.columns.tolist()
y_values = sorted_df_score.iloc[0].tolist()

trace = go.Bar(x=x_values, y=y_values, marker={'color': y_values, 'colorscale': 'Greens'})
fig = go.Figure(data=[trace])

for i in range(len(df_models_results.columns)):
    fig.add_annotation(x=df_models_results.columns[i], y=df_models_results.iloc[0,i],
                       text=str(round(df_models_results.iloc[0,i], 1)),showarrow=False,
                       yshift=df_models_results.iloc[0,i]/5)

fig.update_layout(title='Total Alignment Reduction by Machine Learning models [%]', xaxis_title='Features', yaxis_title='Alignment ammount reduction [%]')
fig.update_layout(width=1200, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.20.0.min.js"></script>                <div id="f2931302-27ad-4373-91df-2b970c3c6ae6" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2931302-27ad-4373-91df-2b970c3c6ae6")) {                    Plotly.newPlot(                        "f2931302-27ad-4373-91df-2b970c3c6ae6",                        [{"marker":{"color":[92.97,89.41,85.2,71.91,69.15,60.68,44.8,37.64,35.95,30.56,27.64,27.18,14.78,8.43,8.21,6.23],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"x":["MdDeflACF","MdSDeflACF","MdCompUHRRem","MdSImRotCheb1","MdTLDAlign","MdHRpar4","MdDeflDC1","TLD.Push","CorrStigUppYUHR","AlignCorrAngleUHR","MdSShiftTube3","ShiftCorrAngleUHR","MdHRSatPar1","MdACRotUpp","MdSImRotCheb0","MdACRotLow"],"y":[92.97,89.41,85.2,71.91,69.15,60.68,44.8,37.64,35.95,30.56,27.64,27.18,14.78,8.43,8.21,6.23],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolarg ...
